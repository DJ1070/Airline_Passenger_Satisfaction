# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, cohen_kappa_score
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from imblearn.over_sampling import RandomOverSampler

# %%
df = pd.read_excel('./Data/satisfaction.xlsx')

# %%
df
# Out:
#             id          satisfaction_v2  Gender      Customer Type  Age  \
# 0        11112                satisfied  Female     Loyal Customer   65
# 1       110278                satisfied    Male     Loyal Customer   47
# 2       103199                satisfied  Female     Loyal Customer   15
# 3        47462                satisfied  Female     Loyal Customer   60
# 4       120011                satisfied  Female     Loyal Customer   70
# ...        ...                      ...     ...                ...  ...
# 129875  119211                satisfied  Female  disloyal Customer   29
# 129876   97768  neutral or dissatisfied    Male  disloyal Customer   63
# 129877  125368  neutral or dissatisfied    Male  disloyal Customer   69
# 129878     251  neutral or dissatisfied    Male  disloyal Customer   66
# 129879   84566  neutral or dissatisfied  Female  disloyal Customer   38
#
#          Type of Travel     Class  Flight Distance  Seat comfort  \
# 0       Personal Travel       Eco              265             0
# 1       Personal Travel  Business             2464             0
# 2       Personal Travel       Eco             2138             0
# 3       Personal Travel       Eco              623             0
# 4       Personal Travel       Eco              354             0
# ...                 ...       ...              ...           ...
# 129875  Personal Travel       Eco             1731             5
# 129876  Personal Travel  Business             2087             2
# 129877  Personal Travel       Eco             2320             3
# 129878  Personal Travel       Eco             2450             3
# 129879  Personal Travel       Eco             4307             3
#
#         Departure/Arrival time convenient  ...  Online support  \
# 0                                       0  ...               2
# 1                                       0  ...               2
# 2                                       0  ...               2
# 3                                       0  ...               3
# 4                                       0  ...               4
# ...                                   ...  ...             ...
# 129875                                  5  ...               2
# 129876                                  3  ...               1
# 129877                                  0  ...               2
# 129878                                  2  ...               2
# 129879                                  4  ...               3
#
#         Ease of Online booking  On-board service  Leg room service  \
# 0                            3                 3                 0
# 1                            3                 4                 4
# 2                            2                 3                 3
# 3                            1                 1                 0
# 4                            2                 2                 0
# ...                        ...               ...               ...
# 129875                       2                 3                 3
# 129876                       3                 2                 3
# 129877                       4                 4                 3
# 129878                       3                 3                 2
# 129879                       4                 5                 5
#
#         Baggage handling  Checkin service  Cleanliness  Online boarding  \
# 0                      3                5            3                2
# 1                      4                2            3                2
# 2                      4                4            4                2
# 3                      1                4            1                3
# 4                      2                4            2                5
# ...                  ...              ...          ...              ...
# 129875                 4                4            4                2
# 129876                 3                1            2                1
# 129877                 4                2            3                2
# 129878                 3                2            1                2
# 129879                 5                3            3                3
#
#         Departure Delay in Minutes  Arrival Delay in Minutes
# 0                                0                       0.0
# 1                              310                     305.0
# 2                                0                       0.0
# 3                                0                       0.0
# 4                                0                       0.0
# ...                            ...                       ...
# 129875                           0                       0.0
# 129876                         174                     172.0
# 129877                         155                     163.0
# 129878                         193                     205.0
# 129879                         185                     186.0
#
# [129880 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['id', 'satisfaction_v2', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
df.columns = ['ID', 'Satisfaction', 'Gender', 'Customer_type', 'Age',
       'Type_of_travel', 'Class', 'Flight_distance', 'Seat_comfort',
       'Departure_arrival_time_convenient', 'Food_and_drink', 'Gate_location',
       'Inflight_wifi_service', 'Inflight_entertainment', 'Online_support',
       'Ease_of_online_booking', 'Onboard_service', 'Leg_room_service',
       'Baggage_handling', 'Checkin_service', 'Cleanliness', 'Online_boarding',
       'Departure_delay_in_minutes', 'Arrival_delay_in_minutes']

# %%
df['Satisfaction'] = df['Satisfaction'].apply(lambda value: 1 
if value == 'satisfied' else 0)

# %%
df['Gender'] = df['Gender'].apply(lambda value: 1 
if value == 'Female' else 0)

# %%
df['Customer_type'] = df['Customer_type'].apply(lambda value: 1 
if value == 'Loyal Customer' else 0)

# %%
df['Type_of_travel'] = df['Type_of_travel'].apply(lambda value: 1 
if value == 'Business travel' else 0)

# %%
df['Class'] = df['Class'].apply(lambda value: 0 
if value == 'Eco' else 1
if value == 'Eco Plus' else 2)

# %%
df.dtypes
# Out:
# ID                                     int64
# Satisfaction                           int64
# Gender                                 int64
# Customer_type                          int64
# Age                                    int64
# Type_of_travel                         int64
# Class                                  int64
# Flight_distance                        int64
# Seat_comfort                           int64
# Departure_arrival_time_convenient      int64
# Food_and_drink                         int64
# Gate_location                          int64
# Inflight_wifi_service                  int64
# Inflight_entertainment                 int64
# Online_support                         int64
# Ease_of_online_booking                 int64
# Onboard_service                        int64
# Leg_room_service                       int64
# Baggage_handling                       int64
# Checkin_service                        int64
# Cleanliness                            int64
# Online_boarding                        int64
# Departure_delay_in_minutes             int64
# Arrival_delay_in_minutes             float64
# dtype: object

# %%
df = df.drop(['ID', 'Departure_delay_in_minutes', 'Online_boarding'], axis = 1)

# %%
df
# Out:
#         Satisfaction  Gender  Customer_type  Age  Type_of_travel  Class  \
# 0                  1       1              1   65               0      0
# 1                  1       0              1   47               0      2
# 2                  1       1              1   15               0      0
# 3                  1       1              1   60               0      0
# 4                  1       1              1   70               0      0
# ...              ...     ...            ...  ...             ...    ...
# 129875             1       1              0   29               0      0
# 129876             0       0              0   63               0      2
# 129877             0       0              0   69               0      0
# 129878             0       0              0   66               0      0
# 129879             0       1              0   38               0      0
#
#         Flight_distance  Seat_comfort  Departure_arrival_time_convenient  \
# 0                   265             0                                  0
# 1                  2464             0                                  0
# 2                  2138             0                                  0
# 3                   623             0                                  0
# 4                   354             0                                  0
# ...                 ...           ...                                ...
# 129875             1731             5                                  5
# 129876             2087             2                                  3
# 129877             2320             3                                  0
# 129878             2450             3                                  2
# 129879             4307             3                                  4
#
#         Food_and_drink  ...  Inflight_entertainment  Online_support  \
# 0                    0  ...                       4               2
# 1                    0  ...                       2               2
# 2                    0  ...                       0               2
# 3                    0  ...                       4               3
# 4                    0  ...                       3               4
# ...                ...  ...                     ...             ...
# 129875               5  ...                       5               2
# 129876               2  ...                       1               1
# 129877               3  ...                       2               2
# 129878               3  ...                       2               2
# 129879               3  ...                       3               3
#
#         Ease_of_online_booking  Onboard_service  Leg_room_service  \
# 0                            3                3                 0
# 1                            3                4                 4
# 2                            2                3                 3
# 3                            1                1                 0
# 4                            2                2                 0
# ...                        ...              ...               ...
# 129875                       2                3                 3
# 129876                       3                2                 3
# 129877                       4                4                 3
# 129878                       3                3                 2
# 129879                       4                5                 5
#
#         Baggage_handling  Checkin_service  Cleanliness  Online_boarding  \
# 0                      3                5            3                2
# 1                      4                2            3                2
# 2                      4                4            4                2
# 3                      1                4            1                3
# 4                      2                4            2                5
# ...                  ...              ...          ...              ...
# 129875                 4                4            4                2
# 129876                 3                1            2                1
# 129877                 4                2            3                2
# 129878                 3                2            1                2
# 129879                 5                3            3                3
#
#         Arrival_delay_in_minutes
# 0                            0.0
# 1                          305.0
# 2                            0.0
# 3                            0.0
# 4                            0.0
# ...                          ...
# 129875                       0.0
# 129876                     172.0
# 129877                     163.0
# 129878                     205.0
# 129879                     186.0
#
# [129880 rows x 22 columns]

# %%
df[df.Arrival_delay_in_minutes.isna() == True]
# Out:
#         Satisfaction  Gender  Customer_type  Age  Type_of_travel  Class  \
# 145                1       1              1   21               0      0
# 246                1       0              1   28               0      0
# 710                1       0              1   28               0      0
# 736                1       0              1    9               0      0
# 818                0       0              1    9               0      0
# ...              ...     ...            ...  ...             ...    ...
# 127739             1       0              1   44               1      2
# 128131             1       0              1   39               1      2
# 128710             1       1              1   45               1      0
# 129774             1       0              0   49               0      0
# 129873             1       1              0   63               0      0
#
#         Flight_distance  Seat_comfort  Departure_arrival_time_convenient  \
# 145                4804             0                                  2
# 246                1364             0                                  3
# 710                1792             0                                  5
# 736                1862             0                                  5
# 818                1668             1                                  0
# ...                 ...           ...                                ...
# 127739             3431             2                                  2
# 128131             1595             4                                  4
# 128710              871             5                                  1
# 129774             1594             5                                  4
# 129873             1942             5                                  5
#
#         Food_and_drink  ...  Inflight_entertainment  Online_support  \
# 145                  0  ...                       0               5
# 246                  0  ...                       0               4
# 710                  0  ...                       0               5
# 736                  0  ...                       0               3
# 818                  1  ...                       1               4
# ...                ...  ...                     ...             ...
# 127739               3  ...                       2               4
# 128131               4  ...                       4               5
# 128710               1  ...                       5               2
# 129774               5  ...                       5               3
# 129873               4  ...                       4               3
#
#         Ease_of_online_booking  Onboard_service  Leg_room_service  \
# 145                          5                4                 1
# 246                          2                1                 1
# 710                          5                4                 4
# 736                          3                5                 3
# 818                          4                4                 5
# ...                        ...              ...               ...
# 127739                       5                5                 5
# 128131                       5                5                 5
# 128710                       5                5                 5
# 129774                       3                1                 4
# 129873                       3                5                 2
#
#         Baggage_handling  Checkin_service  Cleanliness  Online_boarding  \
# 145                    4                2            3                5
# 246                    3                4            3                2
# 710                    5                3            4                5
# 736                    4                4            4                3
# 818                    1                5            1                4
# ...                  ...              ...          ...              ...
# 127739                 5                5            5                4
# 128131                 5                3            5                5
# 128710                 5                1            5                5
# 129774                 3                3            4                3
# 129873                 5                3            5                3
#
#         Arrival_delay_in_minutes
# 145                          NaN
# 246                          NaN
# 710                          NaN
# 736                          NaN
# 818                          NaN
# ...                          ...
# 127739                       NaN
# 128131                       NaN
# 128710                       NaN
# 129774                       NaN
# 129873                       NaN
#
# [393 rows x 22 columns]

# %%
df.Arrival_delay_in_minutes = df.Arrival_delay_in_minutes.fillna(df.Arrival_delay_in_minutes.mean())

# %%
fig, ax = plt.subplots(figsize=(24, 16)) 
sns.heatmap(df.corr(), annot=True, ax = ax)
# Out:
# <AxesSubplot:>

# %%
X = df.iloc[:,1:]
y = np.array(df['Satisfaction'])

X_scaled = StandardScaler().fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=1)

# %%
# Logistic Regression
model_lr = LogisticRegression().fit(X_train, y_train)
model_lr_prediction = model_lr.predict(X_test)
accuracy_lr = accuracy_score(y_test, model_lr_prediction)

conf_lr = confusion_matrix(y_test, model_lr_prediction)
clf_report_lr = classification_report(y_test, model_lr_prediction)

print(f"Accuracy Score of Logistic Regression is : {accuracy_lr}")
print(f"Confusion Matrix : \n{conf_lr}")
print(f"Classification Report : \n{clf_report_lr}")
# Out:
# Accuracy Score of Logistic Regression is : 0.8379273175238682
# Confusion Matrix :
# [[ 9665  2139]
#  [ 2071 12101]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82     11804
#            1       0.85      0.85      0.85     14172
#
#     accuracy                           0.84     25976
#    macro avg       0.84      0.84      0.84     25976
# weighted avg       0.84      0.84      0.84     25976

# %%
kappa_lr = cohen_kappa_score(y_test, model_lr_prediction)
kappa_lr
# Out:
# 0.6729809142478427

# %%
# Decision Tree
model_dt = tree.DecisionTreeClassifier().fit(X_train, y_train)
model_dt_prediction = model_dt.predict(X_test)
accuracy_dt = accuracy_score(y_test, model_dt_prediction)

conf_dt = confusion_matrix(y_test, model_dt_prediction)
clf_report_dt = classification_report(y_test, model_dt_prediction)

print(f"Accuracy Score of Decision Tree is : {accuracy_dt}")
print(f"Confusion Matrix : \n{conf_dt}")
print(f"Classification Report : \n{clf_report_dt}")
# Out:
# Accuracy Score of Decision Tree is : 0.9419464120726825
# Confusion Matrix :
# [[11036   768]
#  [  740 13432]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94     11804
#            1       0.95      0.95      0.95     14172
#
#     accuracy                           0.94     25976
#    macro avg       0.94      0.94      0.94     25976
# weighted avg       0.94      0.94      0.94     25976

# %%
kappa_dt = cohen_kappa_score(y_test, model_dt_prediction)
kappa_dt
# Out:
# 0.8828966411726953

# %%
# K-Fold DecisionTree
model_kfdt = cross_val_score(tree.DecisionTreeClassifier(max_depth = 7), X, y, cv=700)
print('Maximum: ', model_kfdt.max())
print('Mean: ', model_kfdt.mean())

model_kfdt = pd.Series(model_kfdt)
model_kfdt.plot()
# Out:
# Maximum:  1.0
# Mean:  0.9108414497446756
# <AxesSubplot:>

# %%
# KNN
model_knn = KNeighborsClassifier(n_neighbors = 7, metric = 'minkowski', p = 2).fit(X_train, y_train)
model_knn_prediction = model_knn.predict(X_test)
accuracy_knn = accuracy_score(y_test, model_knn_prediction)

conf_knn = confusion_matrix(y_test, model_knn_prediction)
clf_report_knn = classification_report(y_test, model_knn_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_knn}")
print(f"Confusion Matrix : \n{conf_knn}")
print(f"Classification Report : \n{clf_report_knn}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.9286264243917463
# Confusion Matrix :
# [[11153   651]
#  [ 1203 12969]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92     11804
#            1       0.95      0.92      0.93     14172
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
kappa_knn = cohen_kappa_score(y_test, model_knn_prediction)
kappa_knn
# Out:
# 0.8566168116757228

# %%
# Random Forest Classifier
model_rf = RandomForestClassifier(n_estimators=1500, criterion = 'entropy', random_state = 6).fit(X_train, y_train)
model_rf_prediction = model_rf.predict(X_test)
rf = accuracy_score(y_test, model_rf_prediction)
print('Accuracy Score: ', rf)
# Out:
# Accuracy Score:  0.9607329842931938

# %%
kappa_rf = cohen_kappa_score(y_test, model_rf_prediction)
print('Kappa: ', kappa_rf)
# Out:
# Kappa:  0.920956666953379

# %%
# Random Forest
model_rf = RandomForestClassifier(n_estimators=1500).fit(X_train, y_train)
model_rf_prediction = model_rf.predict(X_test)
accuracy_rf = accuracy_score(y_test, model_rf_prediction)

conf_rf = confusion_matrix(y_test, model_rf_prediction)
clf_report_rf = classification_report(y_test, model_rf_prediction)

print(f"Accuracy Score of Random Forest is : {accuracy_rf}")
print(f"Confusion Matrix : \n{conf_rf}")
print(f"Classification Report : \n{clf_report_rf}")
# Out:
# Accuracy Score of Random Forest is : 0.9613104404065291
# Confusion Matrix :
# [[11423   381]
#  [  624 13548]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_rf = cohen_kappa_score(y_test, model_rf_prediction)
kappa_rf
# Out:
# 0.9221064126893194

# %%
# Ada Boost
model_ada = AdaBoostClassifier(n_estimators = 1000).fit(X_train, y_train)
model_ada_prediction = model_ada.predict(X_test)
accuracy_ada = accuracy_score(y_test, model_ada_prediction)

conf_ada = confusion_matrix(y_test, model_ada_prediction)
clf_report_ada = classification_report(y_test, model_ada_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_ada}")
print(f"Confusion Matrix : \n{conf_ada}")
print(f"Classification Report : \n{clf_report_ada}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.9061056359716662
# Confusion Matrix :
# [[10654  1150]
#  [ 1289 12883]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90     11804
#            1       0.92      0.91      0.91     14172
#
#     accuracy                           0.91     25976
#    macro avg       0.91      0.91      0.91     25976
# weighted avg       0.91      0.91      0.91     25976

# %%
kappa_ada = cohen_kappa_score(y_test, model_ada_prediction)
kappa_ada
# Out:
# 0.810823717218921

# %%
# Gradient Boosting Classifier
model_gb = GradientBoostingClassifier().fit(X_train, y_train)
model_gb_prediction = model_gb.predict(X_test)

accuracy_gb = accuracy_score(y_test, model_gb_prediction)
conf_gb = confusion_matrix(y_test, model_gb_prediction)
clf_report_gb = classification_report(y_test, model_gb_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_gb}")
print(f"Confusion Matrix : \n{conf_gb}")
print(f"Classification Report : \n{clf_report_gb}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.9274715121650755
# Confusion Matrix :
# [[10864   940]
#  [  944 13228]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     11804
#            1       0.93      0.93      0.93     14172
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
kappa_gb = cohen_kappa_score(y_test, model_gb_prediction)
kappa_gb
# Out:
# 0.853731590524546

# %%
# XgBoost Classifier
model_xgb = XGBClassifier(booster = 'gbtree', learning_rate = 0.1, max_depth = 5, n_estimators = 180).fit(X_train, y_train)
model_xgb_prediction = model_xgb.predict(X_test)

accuracy_xgb = accuracy_score(y_test, model_xgb_prediction)
conf_xgb = confusion_matrix(y_test, model_xgb_prediction)
clf_report_xgb = classification_report(y_test, model_xgb_prediction)

print(f"Accuracy Score of XgBoost Classifier is : {accuracy_xgb}")
print(f"Confusion Matrix : \n{conf_xgb}")
print(f"Classification Report : \n{clf_report_xgb}")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:40:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy Score of XgBoost Classifier is : 0.9569217739451802
# Confusion Matrix :
# [[11334   470]
#  [  649 13523]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95     11804
#            1       0.97      0.95      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_xgb = cohen_kappa_score(y_test, model_xgb_prediction)
kappa_xgb
# Out:
# 0.91323148596489

# %%
# Cat Boost Classifier
model_cat = CatBoostClassifier(iterations=100).fit(X_train, y_train)
model_cat_prediction = model_cat.predict(X_test)

accuracy_cat = accuracy_score(y_test, model_cat_prediction)
conf_cat = confusion_matrix(y_test, model_cat_prediction)
clf_report_cat = classification_report(y_test, model_cat_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_cat}")
print(f"Confusion Matrix : \n{conf_cat}")
print(f"Classification Report : \n{clf_report_cat}")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.3443416	total: 82.8ms	remaining: 8.2s
# 1:	learn: 0.2609934	total: 138ms	remaining: 6.76s
# 2:	learn: 0.2153750	total: 198ms	remaining: 6.41s
# 3:	learn: 0.2025242	total: 250ms	remaining: 6s
# 4:	learn: 0.1824307	total: 300ms	remaining: 5.7s
# 5:	learn: 0.1729295	total: 349ms	remaining: 5.47s
# 6:	learn: 0.1628843	total: 396ms	remaining: 5.26s
# 7:	learn: 0.1574423	total: 450ms	remaining: 5.18s
# 8:	learn: 0.1537504	total: 503ms	remaining: 5.09s
# 9:	learn: 0.1517733	total: 551ms	remaining: 4.96s
# 10:	learn: 0.1409069	total: 602ms	remaining: 4.87s
# 11:	learn: 0.1393028	total: 653ms	remaining: 4.79s
# 12:	learn: 0.1372074	total: 708ms	remaining: 4.74s
# 13:	learn: 0.1326453	total: 773ms	remaining: 4.75s
# 14:	learn: 0.1297816	total: 846ms	remaining: 4.79s
# 15:	learn: 0.1263587	total: 922ms	remaining: 4.84s
# 16:	learn: 0.1247056	total: 991ms	remaining: 4.84s
# 17:	learn: 0.1230358	total: 1.06s	remaining: 4.85s
# 18:	learn: 0.1214883	total: 1.17s	remaining: 4.99s
# 19:	learn: 0.1203671	total: 1.28s	remaining: 5.14s
# 20:	learn: 0.1187036	total: 1.38s	remaining: 5.21s
# 21:	learn: 0.1160094	total: 1.46s	remaining: 5.17s
# 22:	learn: 0.1141365	total: 1.55s	remaining: 5.2s
# 23:	learn: 0.1131814	total: 1.67s	remaining: 5.29s
# 24:	learn: 0.1117540	total: 1.74s	remaining: 5.23s
# 25:	learn: 0.1106259	total: 1.82s	remaining: 5.18s
# 26:	learn: 0.1085090	total: 1.88s	remaining: 5.08s
# 27:	learn: 0.1064992	total: 1.93s	remaining: 4.96s
# 28:	learn: 0.1058335	total: 1.99s	remaining: 4.87s
# 29:	learn: 0.1043866	total: 2.04s	remaining: 4.76s
# 30:	learn: 0.1033528	total: 2.09s	remaining: 4.65s
# 31:	learn: 0.1029987	total: 2.13s	remaining: 4.53s
# 32:	learn: 0.1021288	total: 2.2s	remaining: 4.46s
# 33:	learn: 0.1017387	total: 2.24s	remaining: 4.35s
# 34:	learn: 0.1012572	total: 2.29s	remaining: 4.25s
# 35:	learn: 0.1005535	total: 2.34s	remaining: 4.16s
# 36:	learn: 0.1002755	total: 2.39s	remaining: 4.07s
# 37:	learn: 0.0999435	total: 2.44s	remaining: 3.98s
# 38:	learn: 0.0995712	total: 2.48s	remaining: 3.89s
# 39:	learn: 0.0989549	total: 2.53s	remaining: 3.8s
# 40:	learn: 0.0980829	total: 2.59s	remaining: 3.73s
# 41:	learn: 0.0977642	total: 2.64s	remaining: 3.65s
# 42:	learn: 0.0974564	total: 2.69s	remaining: 3.56s
# 43:	learn: 0.0970534	total: 2.73s	remaining: 3.48s
# 44:	learn: 0.0961090	total: 2.79s	remaining: 3.41s
# 45:	learn: 0.0950714	total: 2.85s	remaining: 3.34s
# 46:	learn: 0.0945642	total: 2.89s	remaining: 3.26s
# 47:	learn: 0.0939605	total: 2.96s	remaining: 3.21s
# 48:	learn: 0.0936201	total: 3.03s	remaining: 3.15s
# 49:	learn: 0.0931786	total: 3.08s	remaining: 3.08s
# 50:	learn: 0.0925471	total: 3.13s	remaining: 3s
# 51:	learn: 0.0923433	total: 3.18s	remaining: 2.94s
# 52:	learn: 0.0918060	total: 3.23s	remaining: 2.87s
# 53:	learn: 0.0914440	total: 3.28s	remaining: 2.79s
# 54:	learn: 0.0910220	total: 3.33s	remaining: 2.72s
# 55:	learn: 0.0906555	total: 3.37s	remaining: 2.65s
# 56:	learn: 0.0902489	total: 3.43s	remaining: 2.59s
# 57:	learn: 0.0900352	total: 3.5s	remaining: 2.54s
# 58:	learn: 0.0897264	total: 3.56s	remaining: 2.48s
# 59:	learn: 0.0894608	total: 3.64s	remaining: 2.43s
# 60:	learn: 0.0892105	total: 3.7s	remaining: 2.37s
# 61:	learn: 0.0888987	total: 3.77s	remaining: 2.31s
# 62:	learn: 0.0886758	total: 3.84s	remaining: 2.26s
# 63:	learn: 0.0884561	total: 3.91s	remaining: 2.2s
# 64:	learn: 0.0882889	total: 3.98s	remaining: 2.14s
# 65:	learn: 0.0881306	total: 4.04s	remaining: 2.08s
# 66:	learn: 0.0878895	total: 4.12s	remaining: 2.03s
# 67:	learn: 0.0874639	total: 4.16s	remaining: 1.96s
# 68:	learn: 0.0872438	total: 4.21s	remaining: 1.89s
# 69:	learn: 0.0867999	total: 4.27s	remaining: 1.83s
# 70:	learn: 0.0864322	total: 4.32s	remaining: 1.76s
# 71:	learn: 0.0861267	total: 4.37s	remaining: 1.7s
# 72:	learn: 0.0858066	total: 4.42s	remaining: 1.63s
# 73:	learn: 0.0855821	total: 4.47s	remaining: 1.57s
# 74:	learn: 0.0854414	total: 4.53s	remaining: 1.51s
# 75:	learn: 0.0852946	total: 4.58s	remaining: 1.45s
# 76:	learn: 0.0850122	total: 4.63s	remaining: 1.38s
# 77:	learn: 0.0847526	total: 4.69s	remaining: 1.32s
# 78:	learn: 0.0844347	total: 4.77s	remaining: 1.27s
# 79:	learn: 0.0842463	total: 4.87s	remaining: 1.22s
# 80:	learn: 0.0841123	total: 4.98s	remaining: 1.17s
# 81:	learn: 0.0838147	total: 5.07s	remaining: 1.11s
# 82:	learn: 0.0833942	total: 5.18s	remaining: 1.06s
# 83:	learn: 0.0832626	total: 5.29s	remaining: 1.01s
# 84:	learn: 0.0830241	total: 5.4s	remaining: 953ms
# 85:	learn: 0.0828257	total: 5.49s	remaining: 893ms
# 86:	learn: 0.0825655	total: 5.56s	remaining: 830ms
# 87:	learn: 0.0822938	total: 5.63s	remaining: 767ms
# 88:	learn: 0.0819348	total: 5.69s	remaining: 704ms
# 89:	learn: 0.0818215	total: 5.77s	remaining: 641ms
# 90:	learn: 0.0815144	total: 5.84s	remaining: 577ms
# 91:	learn: 0.0814497	total: 5.9s	remaining: 513ms
# 92:	learn: 0.0813251	total: 5.97s	remaining: 449ms
# 93:	learn: 0.0813250	total: 6.01s	remaining: 383ms
# 94:	learn: 0.0812273	total: 6.07s	remaining: 319ms
# 95:	learn: 0.0811686	total: 6.12s	remaining: 255ms
# 96:	learn: 0.0808232	total: 6.2s	remaining: 192ms
# 97:	learn: 0.0806955	total: 6.28s	remaining: 128ms
# 98:	learn: 0.0805719	total: 6.37s	remaining: 64.3ms
# 99:	learn: 0.0803535	total: 6.46s	remaining: 0us
# Accuracy Score of Cat Boost Classifier is : 0.9591931013242994
# Confusion Matrix :
# [[11345   459]
#  [  601 13571]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_cat = cohen_kappa_score(y_test, model_cat_prediction)
kappa_cat
# Out:
# 0.9177849092973457

# %%
# Extra Trees Classifier
model_etc = ExtraTreesClassifier().fit(X_train, y_train)
model_etc_prediction = model_etc.predict(X_test)

accuracy_etc = accuracy_score(y_test, model_etc_prediction)
conf_etc = confusion_matrix(y_test, model_etc_prediction)
clf_report_etc = classification_report(y_test, model_etc_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_etc}")
print(f"Confusion Matrix : \n{conf_etc}")
print(f"Classification Report : \n{clf_report_etc}")
# Out:
# Accuracy Score of Cat Boost Classifier is : 0.9600400369571912
# Confusion Matrix :
# [[11380   424]
#  [  614 13558]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_etc = cohen_kappa_score(y_test, model_etc_prediction)
kappa_etc
# Out:
# 0.9195185746571478

# %%
# LGBM Classifier
model_lgbm = LGBMClassifier(learning_rate = 1).fit(X_train, y_train)
model_lgbm_prediction = model_lgbm.predict(X_test)

accuracy_lgbm = accuracy_score(y_test, model_lgbm_prediction)
conf_lgbm = confusion_matrix(y_test, model_lgbm_prediction)
clf_report_lgbm = classification_report(y_test, model_lgbm_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_lgbm}")
print(f"Confusion Matrix : \n{conf_lgbm}")
print(f"Classification Report : \n{clf_report_lgbm}")
# Out:
# Accuracy Score of Cat Boost Classifier is : 0.9275100092392978
# Confusion Matrix :
# [[10904   900]
#  [  983 13189]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     11804
#            1       0.94      0.93      0.93     14172
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
kappa_lgbm = cohen_kappa_score(y_test, model_lgbm_prediction)
kappa_lgbm
# Out:
# 0.853890920405084

# %%
# Voting Classifier
classifiers = [('Gradient Boosting Classifier', model_gb), ('Cat Boost Classifier', model_cat), ('XGboost', model_xgb),  
               ('Decision Tree', model_dt), ('Extra Tree', model_etc), ('Light Gradient', model_lgbm), ('Random Forest', model_rf), 
               ('Ada Boost', model_ada), ('Logistic', model_lr), ('Knn', model_knn)]
model_vc = VotingClassifier(estimators = classifiers).fit(X_train, y_train)
model_vc_prediction = model_vc.predict(X_test)

accuracy_vc = accuracy_score(y_test, model_vc_prediction)
conf_vc = confusion_matrix(y_test, model_vc_prediction)
clf_report_vc = classification_report(y_test, model_vc_prediction)

print(f"Accuracy Score of Voting Classifier is : {accuracy_vc}")
print(f"Confusion Matrix : \n{conf_vc}")
print(f"Classification Report : \n{clf_report_vc}")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.3443416	total: 44.4ms	remaining: 4.4s
# 1:	learn: 0.2609934	total: 86.6ms	remaining: 4.24s
# 2:	learn: 0.2153750	total: 131ms	remaining: 4.22s
# 3:	learn: 0.2025242	total: 174ms	remaining: 4.18s
# 4:	learn: 0.1824307	total: 259ms	remaining: 4.92s
# 5:	learn: 0.1729295	total: 324ms	remaining: 5.07s
# 6:	learn: 0.1628843	total: 400ms	remaining: 5.31s
# 7:	learn: 0.1574423	total: 461ms	remaining: 5.3s
# 8:	learn: 0.1537504	total: 527ms	remaining: 5.33s
# 9:	learn: 0.1517733	total: 588ms	remaining: 5.29s
# 10:	learn: 0.1409069	total: 661ms	remaining: 5.35s
# 11:	learn: 0.1393028	total: 729ms	remaining: 5.34s
# 12:	learn: 0.1372074	total: 792ms	remaining: 5.3s
# 13:	learn: 0.1326453	total: 860ms	remaining: 5.29s
# 14:	learn: 0.1297816	total: 911ms	remaining: 5.16s
# 15:	learn: 0.1263587	total: 957ms	remaining: 5.02s
# 16:	learn: 0.1247056	total: 1s	remaining: 4.9s
# 17:	learn: 0.1230358	total: 1.05s	remaining: 4.8s
# 18:	learn: 0.1214883	total: 1.11s	remaining: 4.75s
# 19:	learn: 0.1203671	total: 1.18s	remaining: 4.71s
# 20:	learn: 0.1187036	total: 1.25s	remaining: 4.7s
# 21:	learn: 0.1160094	total: 1.32s	remaining: 4.68s
# 22:	learn: 0.1141365	total: 1.39s	remaining: 4.64s
# 23:	learn: 0.1131814	total: 1.47s	remaining: 4.65s
# 24:	learn: 0.1117540	total: 1.55s	remaining: 4.65s
# 25:	learn: 0.1106259	total: 1.65s	remaining: 4.71s
# 26:	learn: 0.1085090	total: 1.73s	remaining: 4.68s
# 27:	learn: 0.1064992	total: 1.8s	remaining: 4.64s
# 28:	learn: 0.1058335	total: 1.86s	remaining: 4.54s
# 29:	learn: 0.1043866	total: 1.94s	remaining: 4.52s
# 30:	learn: 0.1033528	total: 2s	remaining: 4.44s
# 31:	learn: 0.1029987	total: 2.04s	remaining: 4.33s
# 32:	learn: 0.1021288	total: 2.09s	remaining: 4.25s
# 33:	learn: 0.1017387	total: 2.14s	remaining: 4.16s
# 34:	learn: 0.1012572	total: 2.19s	remaining: 4.07s
# 35:	learn: 0.1005535	total: 2.25s	remaining: 3.99s
# 36:	learn: 0.1002755	total: 2.3s	remaining: 3.92s
# 37:	learn: 0.0999435	total: 2.35s	remaining: 3.83s
# 38:	learn: 0.0995712	total: 2.4s	remaining: 3.75s
# 39:	learn: 0.0989549	total: 2.44s	remaining: 3.66s
# 40:	learn: 0.0980829	total: 2.49s	remaining: 3.58s
# 41:	learn: 0.0977642	total: 2.54s	remaining: 3.51s
# 42:	learn: 0.0974564	total: 2.59s	remaining: 3.43s
# 43:	learn: 0.0970534	total: 2.63s	remaining: 3.35s
# 44:	learn: 0.0961090	total: 2.68s	remaining: 3.27s
# 45:	learn: 0.0950714	total: 2.73s	remaining: 3.21s
# 46:	learn: 0.0945642	total: 2.78s	remaining: 3.13s
# 47:	learn: 0.0939605	total: 2.83s	remaining: 3.06s
# 48:	learn: 0.0936201	total: 2.87s	remaining: 2.98s
# 49:	learn: 0.0931786	total: 2.92s	remaining: 2.92s
# 50:	learn: 0.0925471	total: 2.98s	remaining: 2.87s
# 51:	learn: 0.0923433	total: 3.04s	remaining: 2.81s
# 52:	learn: 0.0918060	total: 3.12s	remaining: 2.76s
# 53:	learn: 0.0914440	total: 3.18s	remaining: 2.71s
# 54:	learn: 0.0910220	total: 3.24s	remaining: 2.65s
# 55:	learn: 0.0906555	total: 3.31s	remaining: 2.6s
# 56:	learn: 0.0902489	total: 3.37s	remaining: 2.54s
# 57:	learn: 0.0900352	total: 3.45s	remaining: 2.5s
# 58:	learn: 0.0897264	total: 3.52s	remaining: 2.44s
# 59:	learn: 0.0894608	total: 3.58s	remaining: 2.39s
# 60:	learn: 0.0892105	total: 3.63s	remaining: 2.32s
# 61:	learn: 0.0888987	total: 3.68s	remaining: 2.25s
# 62:	learn: 0.0886758	total: 3.74s	remaining: 2.19s
# 63:	learn: 0.0884561	total: 3.78s	remaining: 2.13s
# 64:	learn: 0.0882889	total: 3.82s	remaining: 2.06s
# 65:	learn: 0.0881306	total: 3.87s	remaining: 1.99s
# 66:	learn: 0.0878895	total: 3.92s	remaining: 1.93s
# 67:	learn: 0.0874639	total: 3.97s	remaining: 1.87s
# 68:	learn: 0.0872438	total: 4.02s	remaining: 1.8s
# 69:	learn: 0.0867999	total: 4.08s	remaining: 1.75s
# 70:	learn: 0.0864322	total: 4.15s	remaining: 1.69s
# 71:	learn: 0.0861267	total: 4.22s	remaining: 1.64s
# 72:	learn: 0.0858066	total: 4.28s	remaining: 1.58s
# 73:	learn: 0.0855821	total: 4.36s	remaining: 1.53s
# 74:	learn: 0.0854414	total: 4.42s	remaining: 1.47s
# 75:	learn: 0.0852946	total: 4.47s	remaining: 1.41s
# 76:	learn: 0.0850122	total: 4.55s	remaining: 1.36s
# 77:	learn: 0.0847526	total: 4.61s	remaining: 1.3s
# 78:	learn: 0.0844347	total: 4.67s	remaining: 1.24s
# 79:	learn: 0.0842463	total: 4.74s	remaining: 1.19s
# 80:	learn: 0.0841123	total: 4.79s	remaining: 1.12s
# 81:	learn: 0.0838147	total: 4.83s	remaining: 1.06s
# 82:	learn: 0.0833942	total: 4.88s	remaining: 999ms
# 83:	learn: 0.0832626	total: 4.93s	remaining: 939ms
# 84:	learn: 0.0830241	total: 4.98s	remaining: 878ms
# 85:	learn: 0.0828257	total: 5.02s	remaining: 817ms
# 86:	learn: 0.0825655	total: 5.07s	remaining: 757ms
# 87:	learn: 0.0822938	total: 5.12s	remaining: 698ms
# 88:	learn: 0.0819348	total: 5.17s	remaining: 639ms
# 89:	learn: 0.0818215	total: 5.22s	remaining: 580ms
# 90:	learn: 0.0815144	total: 5.28s	remaining: 522ms
# 91:	learn: 0.0814497	total: 5.33s	remaining: 463ms
# 92:	learn: 0.0813251	total: 5.37s	remaining: 404ms
# 93:	learn: 0.0813250	total: 5.4s	remaining: 344ms
# 94:	learn: 0.0812273	total: 5.44s	remaining: 286ms
# 95:	learn: 0.0811686	total: 5.48s	remaining: 228ms
# 96:	learn: 0.0808232	total: 5.53s	remaining: 171ms
# 97:	learn: 0.0806955	total: 5.58s	remaining: 114ms
# 98:	learn: 0.0805719	total: 5.63s	remaining: 56.9ms
# 99:	learn: 0.0803535	total: 5.68s	remaining: 0us
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:42:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy Score of Voting Classifier is : 0.957114259316292
# Confusion Matrix :
# [[11393   411]
#  [  703 13469]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     11804
#            1       0.97      0.95      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_vc = cohen_kappa_score(y_test, model_vc_prediction)
kappa_vc
# Out:
# 0.9136881346102763

# %%
# Models Comparison
models = pd.DataFrame({
    'Model' : ['Logistic Regression', 'KNN', 'Decision Tree Classifier', 'Random Forest Classifier','Ada Boost Classifier',
             'Gradient Boosting Classifier', 'XgBoost', 'Cat Boost', 'Extra Trees Classifier', 'LGBM', 'Voting Classifier', 'K-Fold Decision Tree'],
    'Score' : [accuracy_lr, accuracy_knn, accuracy_dt, accuracy_rf, accuracy_ada, accuracy_gb, accuracy_xgb, accuracy_cat, 
              accuracy_etc, accuracy_lgbm, accuracy_vc, model_kfdt.mean()],
    'Kappa' : [kappa_lr, kappa_knn, kappa_dt, kappa_rf, kappa_ada, kappa_gb, kappa_xgb, kappa_cat, kappa_etc, kappa_lgbm, 
              kappa_vc, model_kfdt.mean()]
})

# Sorting the results by Kappa values
models_sorted = models.sort_values(by = 'Kappa', ascending = False)
models_sorted.reset_index(drop = True, inplace = True)

# %%
# PLOT: All Kappa values as comparison

plt.bar(x=models_sorted.Model, height = models_sorted.Kappa, color = 'c', width = 0.5)
#plt.grid()
plt.title('Machine Learning Models in Prediction of Airline Passenger`s Satisfaction')
plt.xlabel('Exploration Methods', fontsize=15)
plt.ylabel('Kappa', fontsize=15)
plt.ylim(0, 1)
plt.xticks(rotation=90)
plt.rcParams['figure.figsize'] = [5, 8]

for i in models_sorted.index:
  plt.text(x = i, 
           y = models_sorted.Kappa[i], 
           s = round(models_sorted.Kappa[i], 3), 
           horizontalalignment='center',
           verticalalignment='bottom',
           size = 11)

plt.show()
