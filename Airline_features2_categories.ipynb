# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, cohen_kappa_score
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from imblearn.over_sampling import RandomOverSampler

# %%
df = pd.read_excel('./Data/satisfaction.xlsx')

# %%
df
# Out:
#             id          satisfaction_v2  Gender      Customer Type  Age  \
# 0        11112                satisfied  Female     Loyal Customer   65
# 1       110278                satisfied    Male     Loyal Customer   47
# 2       103199                satisfied  Female     Loyal Customer   15
# 3        47462                satisfied  Female     Loyal Customer   60
# 4       120011                satisfied  Female     Loyal Customer   70
# ...        ...                      ...     ...                ...  ...
# 129875  119211                satisfied  Female  disloyal Customer   29
# 129876   97768  neutral or dissatisfied    Male  disloyal Customer   63
# 129877  125368  neutral or dissatisfied    Male  disloyal Customer   69
# 129878     251  neutral or dissatisfied    Male  disloyal Customer   66
# 129879   84566  neutral or dissatisfied  Female  disloyal Customer   38
#
#          Type of Travel     Class  Flight Distance  Seat comfort  \
# 0       Personal Travel       Eco              265             0
# 1       Personal Travel  Business             2464             0
# 2       Personal Travel       Eco             2138             0
# 3       Personal Travel       Eco              623             0
# 4       Personal Travel       Eco              354             0
# ...                 ...       ...              ...           ...
# 129875  Personal Travel       Eco             1731             5
# 129876  Personal Travel  Business             2087             2
# 129877  Personal Travel       Eco             2320             3
# 129878  Personal Travel       Eco             2450             3
# 129879  Personal Travel       Eco             4307             3
#
#         Departure/Arrival time convenient  ...  Online support  \
# 0                                       0  ...               2
# 1                                       0  ...               2
# 2                                       0  ...               2
# 3                                       0  ...               3
# 4                                       0  ...               4
# ...                                   ...  ...             ...
# 129875                                  5  ...               2
# 129876                                  3  ...               1
# 129877                                  0  ...               2
# 129878                                  2  ...               2
# 129879                                  4  ...               3
#
#         Ease of Online booking  On-board service  Leg room service  \
# 0                            3                 3                 0
# 1                            3                 4                 4
# 2                            2                 3                 3
# 3                            1                 1                 0
# 4                            2                 2                 0
# ...                        ...               ...               ...
# 129875                       2                 3                 3
# 129876                       3                 2                 3
# 129877                       4                 4                 3
# 129878                       3                 3                 2
# 129879                       4                 5                 5
#
#         Baggage handling  Checkin service  Cleanliness  Online boarding  \
# 0                      3                5            3                2
# 1                      4                2            3                2
# 2                      4                4            4                2
# 3                      1                4            1                3
# 4                      2                4            2                5
# ...                  ...              ...          ...              ...
# 129875                 4                4            4                2
# 129876                 3                1            2                1
# 129877                 4                2            3                2
# 129878                 3                2            1                2
# 129879                 5                3            3                3
#
#         Departure Delay in Minutes  Arrival Delay in Minutes
# 0                                0                       0.0
# 1                              310                     305.0
# 2                                0                       0.0
# 3                                0                       0.0
# 4                                0                       0.0
# ...                            ...                       ...
# 129875                           0                       0.0
# 129876                         174                     172.0
# 129877                         155                     163.0
# 129878                         193                     205.0
# 129879                         185                     186.0
#
# [129880 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['id', 'satisfaction_v2', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
df.columns = ['ID', 'Satisfaction', 'Gender', 'Customer_type', 'Age',
       'Type_of_travel', 'Class', 'Flight_distance', 'Seat_comfort',
       'Departure_arrival_time_convenient', 'Food_and_drink', 'Gate_location',
       'Inflight_wifi_service', 'Inflight_entertainment', 'Online_support',
       'Ease_of_online_booking', 'Onboard_service', 'Leg_room_service',
       'Baggage_handling', 'Checkin_service', 'Cleanliness', 'Online_boarding',
       'Departure_delay_in_minutes', 'Arrival_delay_in_minutes']

# %%
df['Satisfaction'] = df['Satisfaction'].apply(lambda value: 1 
if value == 'satisfied' else 0)

df['Gender'] = df['Gender'].apply(lambda value: 1 
if value == 'Female' else 0).astype('category')

df['Customer_type'] = df['Customer_type'].apply(lambda value: 1 
if value == 'Loyal Customer' else 0)

df['Type_of_travel'] = df['Type_of_travel'].apply(lambda value: 1 
if value == 'Business travel' else 0).astype('category')

df['Class'] = df['Class'].apply(lambda value: 0 
if value == 'Eco' else 1
if value == 'Eco Plus' else 2).astype('category')

# %%
df.dtypes
# Out:
# ID                                      int64
# Satisfaction                            int64
# Gender                               category
# Customer_type                           int64
# Age                                     int64
# Type_of_travel                       category
# Class                                category
# Flight_distance                         int64
# Seat_comfort                            int64
# Departure_arrival_time_convenient       int64
# Food_and_drink                          int64
# Gate_location                           int64
# Inflight_wifi_service                   int64
# Inflight_entertainment                  int64
# Online_support                          int64
# Ease_of_online_booking                  int64
# Onboard_service                         int64
# Leg_room_service                        int64
# Baggage_handling                        int64
# Checkin_service                         int64
# Cleanliness                             int64
# Online_boarding                         int64
# Departure_delay_in_minutes              int64
# Arrival_delay_in_minutes              float64
# dtype: object

# %%
df[df.Arrival_delay_in_minutes.isna() == True].count()
# Out:
# Satisfaction                         393
# Gender                               393
# Customer_type                        393
# Age                                  393
# Type_of_travel                       393
# Class                                393
# Flight_distance                      393
# Seat_comfort                         393
# Departure_arrival_time_convenient    393
# Food_and_drink                       393
# Gate_location                        393
# Inflight_wifi_service                393
# Inflight_entertainment               393
# Online_support                       393
# Ease_of_online_booking               393
# Onboard_service                      393
# Leg_room_service                     393
# Baggage_handling                     393
# Checkin_service                      393
# Cleanliness                          393
# Arrival_delay_in_minutes               0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(24, 16)) 
sns.heatmap(df.corr(), annot=True, ax = ax)
# Out:
# <AxesSubplot:>

# %%
df = df.drop(['ID', 'Departure_delay_in_minutes', 'Online_boarding'], axis = 1)

# %%
df.Arrival_delay_in_minutes = df.Arrival_delay_in_minutes.fillna(df.Arrival_delay_in_minutes.mean())

# %%
X = df.iloc[:,1:]
y = np.array(df['Satisfaction'])

X_scaled = StandardScaler().fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=1)

# %%
# Logistic Regression
model_lr = LogisticRegression().fit(X_train, y_train)
model_lr_prediction = model_lr.predict(X_test)
accuracy_lr = accuracy_score(y_test, model_lr_prediction)

conf_lr = confusion_matrix(y_test, model_lr_prediction)
clf_report_lr = classification_report(y_test, model_lr_prediction)

print(f"Accuracy Score of Logistic Regression is : {accuracy_lr}")
print(f"Confusion Matrix : \n{conf_lr}")
print(f"Classification Report : \n{clf_report_lr}")
# Out:
# Accuracy Score of Logistic Regression is : 0.8378888204496459
# Confusion Matrix :
# [[ 9652  2152]
#  [ 2059 12113]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82     11804
#            1       0.85      0.85      0.85     14172
#
#     accuracy                           0.84     25976
#    macro avg       0.84      0.84      0.84     25976
# weighted avg       0.84      0.84      0.84     25976

# %%
kappa_lr = cohen_kappa_score(y_test, model_lr_prediction)
kappa_lr
# Out:
# 0.6728453221707859

# %%
# Decision Tree
model_dt = tree.DecisionTreeClassifier().fit(X_train, y_train)
model_dt_prediction = model_dt.predict(X_test)
accuracy_dt = accuracy_score(y_test, model_dt_prediction)

conf_dt = confusion_matrix(y_test, model_dt_prediction)
clf_report_dt = classification_report(y_test, model_dt_prediction)

print(f"Accuracy Score of Decision Tree is : {accuracy_dt}")
print(f"Confusion Matrix : \n{conf_dt}")
print(f"Classification Report : \n{clf_report_dt}")
# Out:
# Accuracy Score of Decision Tree is : 0.9419079149984602
# Confusion Matrix :
# [[11030   774]
#  [  735 13437]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94     11804
#            1       0.95      0.95      0.95     14172
#
#     accuracy                           0.94     25976
#    macro avg       0.94      0.94      0.94     25976
# weighted avg       0.94      0.94      0.94     25976

# %%
kappa_dt = cohen_kappa_score(y_test, model_dt_prediction)
kappa_dt
# Out:
# 0.8828098608305166

# %%
# K-Fold DecisionTree
model_kfdt = cross_val_score(tree.DecisionTreeClassifier(max_depth = 7), X, y, cv=700)
print('Maximum: ', model_kfdt.max())
print('Mean: ', model_kfdt.mean())

model_kfdt = pd.Series(model_kfdt)
model_kfdt.plot()
# Out:
# Maximum:  1.0
# Mean:  0.9103727736953543
# <AxesSubplot:>

# %%
# KNN
model_knn = KNeighborsClassifier(n_neighbors = 7, metric = 'minkowski', p = 2).fit(X_train, y_train)
model_knn_prediction = model_knn.predict(X_test)
accuracy_knn = accuracy_score(y_test, model_knn_prediction)

conf_knn = confusion_matrix(y_test, model_knn_prediction)
clf_report_knn = classification_report(y_test, model_knn_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_knn}")
print(f"Confusion Matrix : \n{conf_knn}")
print(f"Classification Report : \n{clf_report_knn}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.93032029565753
# Confusion Matrix :
# [[11153   651]
#  [ 1159 13013]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92     11804
#            1       0.95      0.92      0.93     14172
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
kappa_knn = cohen_kappa_score(y_test, model_knn_prediction)
kappa_knn
# Out:
# 0.8599762126792329

# %%
# Random Forest Classifier
model_rf = RandomForestClassifier(n_estimators=1500, criterion = 'entropy', random_state = 6).fit(X_train, y_train)
model_rf_prediction = model_rf.predict(X_test)
rf = accuracy_score(y_test, model_rf_prediction)
print('Accuracy Score: ', rf)
# Out:
# Accuracy Score:  0.9610024638127502

# %%
kappa_rf = cohen_kappa_score(y_test, model_rf_prediction)
print('Kappa: ', kappa_rf)
# Out:
# Kappa:  0.9214952390835738

# %%
# Random Forest
model_rf = RandomForestClassifier(n_estimators=1500).fit(X_train, y_train)
model_rf_prediction = model_rf.predict(X_test)
accuracy_rf = accuracy_score(y_test, model_rf_prediction)

conf_rf = confusion_matrix(y_test, model_rf_prediction)
clf_report_rf = classification_report(y_test, model_rf_prediction)

print(f"Accuracy Score of Random Forest is : {accuracy_rf}")
print(f"Confusion Matrix : \n{conf_rf}")
print(f"Classification Report : \n{clf_report_rf}")
# Out:
# Accuracy Score of Random Forest is : 0.9605789959963043
# Confusion Matrix :
# [[11416   388]
#  [  636 13536]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_rf = cohen_kappa_score(y_test, model_rf_prediction)
kappa_rf
# Out:
# 0.9206366013302787

# %%
# Ada Boost
model_ada = AdaBoostClassifier(n_estimators = 1000).fit(X_train, y_train)
model_ada_prediction = model_ada.predict(X_test)
accuracy_ada = accuracy_score(y_test, model_ada_prediction)

conf_ada = confusion_matrix(y_test, model_ada_prediction)
clf_report_ada = classification_report(y_test, model_ada_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_ada}")
print(f"Confusion Matrix : \n{conf_ada}")
print(f"Classification Report : \n{clf_report_ada}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.905451185709886
# Confusion Matrix :
# [[10630  1174]
#  [ 1282 12890]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90     11804
#            1       0.92      0.91      0.91     14172
#
#     accuracy                           0.91     25976
#    macro avg       0.90      0.91      0.90     25976
# weighted avg       0.91      0.91      0.91     25976

# %%
kappa_ada = cohen_kappa_score(y_test, model_ada_prediction)
kappa_ada
# Out:
# 0.8094633811142379

# %%
# Gradient Boosting Classifier
model_gb = GradientBoostingClassifier().fit(X_train, y_train)
model_gb_prediction = model_gb.predict(X_test)

accuracy_gb = accuracy_score(y_test, model_gb_prediction)
conf_gb = confusion_matrix(y_test, model_gb_prediction)
clf_report_gb = classification_report(y_test, model_gb_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_gb}")
print(f"Confusion Matrix : \n{conf_gb}")
print(f"Classification Report : \n{clf_report_gb}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.9267015706806283
# Confusion Matrix :
# [[10845   959]
#  [  945 13227]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     11804
#            1       0.93      0.93      0.93     14172
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
kappa_gb = cohen_kappa_score(y_test, model_gb_prediction)
kappa_gb
# Out:
# 0.8521600132844134

# %%
# XgBoost Classifier
model_xgb = XGBClassifier(booster = 'gbtree', learning_rate = 0.1, max_depth = 5, n_estimators = 180).fit(X_train, y_train)
model_xgb_prediction = model_xgb.predict(X_test)

accuracy_xgb = accuracy_score(y_test, model_xgb_prediction)
conf_xgb = confusion_matrix(y_test, model_xgb_prediction)
clf_report_xgb = classification_report(y_test, model_xgb_prediction)

print(f"Accuracy Score of XgBoost Classifier is : {accuracy_xgb}")
print(f"Confusion Matrix : \n{conf_xgb}")
print(f"Classification Report : \n{clf_report_xgb}")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:47:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy Score of XgBoost Classifier is : 0.9564213119802895
# Confusion Matrix :
# [[11321   483]
#  [  649 13523]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95     11804
#            1       0.97      0.95      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_xgb = cohen_kappa_score(y_test, model_xgb_prediction)
kappa_xgb
# Out:
# 0.912215384559535

# %%
# Cat Boost Classifier
model_cat = CatBoostClassifier(iterations=100).fit(X_train, y_train)
model_cat_prediction = model_cat.predict(X_test)

accuracy_cat = accuracy_score(y_test, model_cat_prediction)
conf_cat = confusion_matrix(y_test, model_cat_prediction)
clf_report_cat = classification_report(y_test, model_cat_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_cat}")
print(f"Confusion Matrix : \n{conf_cat}")
print(f"Classification Report : \n{clf_report_cat}")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.3579941	total: 220ms	remaining: 21.8s
# 1:	learn: 0.2655886	total: 267ms	remaining: 13.1s
# 2:	learn: 0.2148593	total: 307ms	remaining: 9.92s
# 3:	learn: 0.1924494	total: 351ms	remaining: 8.43s
# 4:	learn: 0.1819402	total: 390ms	remaining: 7.41s
# 5:	learn: 0.1699435	total: 442ms	remaining: 6.92s
# 6:	learn: 0.1632105	total: 491ms	remaining: 6.52s
# 7:	learn: 0.1574021	total: 562ms	remaining: 6.47s
# 8:	learn: 0.1555396	total: 617ms	remaining: 6.24s
# 9:	learn: 0.1532482	total: 680ms	remaining: 6.12s
# 10:	learn: 0.1508899	total: 742ms	remaining: 6s
# 11:	learn: 0.1474065	total: 796ms	remaining: 5.84s
# 12:	learn: 0.1403142	total: 857ms	remaining: 5.73s
# 13:	learn: 0.1387427	total: 918ms	remaining: 5.64s
# 14:	learn: 0.1356071	total: 977ms	remaining: 5.54s
# 15:	learn: 0.1333716	total: 1.04s	remaining: 5.46s
# 16:	learn: 0.1319376	total: 1.09s	remaining: 5.35s
# 17:	learn: 0.1296764	total: 1.16s	remaining: 5.26s
# 18:	learn: 0.1256144	total: 1.21s	remaining: 5.15s
# 19:	learn: 0.1242449	total: 1.26s	remaining: 5.03s
# 20:	learn: 0.1231622	total: 1.3s	remaining: 4.9s
# 21:	learn: 0.1210017	total: 1.35s	remaining: 4.77s
# 22:	learn: 0.1198436	total: 1.4s	remaining: 4.67s
# 23:	learn: 0.1170150	total: 1.45s	remaining: 4.59s
# 24:	learn: 0.1148575	total: 1.5s	remaining: 4.5s
# 25:	learn: 0.1134539	total: 1.54s	remaining: 4.39s
# 26:	learn: 0.1127993	total: 1.59s	remaining: 4.31s
# 27:	learn: 0.1113738	total: 1.65s	remaining: 4.23s
# 28:	learn: 0.1097932	total: 1.69s	remaining: 4.14s
# 29:	learn: 0.1077473	total: 1.73s	remaining: 4.04s
# 30:	learn: 0.1061581	total: 1.78s	remaining: 3.97s
# 31:	learn: 0.1053008	total: 1.85s	remaining: 3.92s
# 32:	learn: 0.1045609	total: 1.9s	remaining: 3.86s
# 33:	learn: 0.1040806	total: 1.96s	remaining: 3.8s
# 34:	learn: 0.1034349	total: 2.02s	remaining: 3.75s
# 35:	learn: 0.1019287	total: 2.08s	remaining: 3.69s
# 36:	learn: 0.1008140	total: 2.13s	remaining: 3.64s
# 37:	learn: 0.1004271	total: 2.2s	remaining: 3.58s
# 38:	learn: 0.0998349	total: 2.26s	remaining: 3.53s
# 39:	learn: 0.0994602	total: 2.31s	remaining: 3.47s
# 40:	learn: 0.0986898	total: 2.38s	remaining: 3.43s
# 41:	learn: 0.0983351	total: 2.45s	remaining: 3.38s
# 42:	learn: 0.0974954	total: 2.51s	remaining: 3.32s
# 43:	learn: 0.0972606	total: 2.56s	remaining: 3.27s
# 44:	learn: 0.0968655	total: 2.61s	remaining: 3.19s
# 45:	learn: 0.0963943	total: 2.65s	remaining: 3.11s
# 46:	learn: 0.0959713	total: 2.69s	remaining: 3.04s
# 47:	learn: 0.0956220	total: 2.74s	remaining: 2.97s
# 48:	learn: 0.0953062	total: 2.78s	remaining: 2.89s
# 49:	learn: 0.0947707	total: 2.82s	remaining: 2.82s
# 50:	learn: 0.0941133	total: 2.85s	remaining: 2.74s
# 51:	learn: 0.0937078	total: 2.89s	remaining: 2.67s
# 52:	learn: 0.0934902	total: 2.93s	remaining: 2.6s
# 53:	learn: 0.0928423	total: 2.97s	remaining: 2.53s
# 54:	learn: 0.0920409	total: 3.01s	remaining: 2.46s
# 55:	learn: 0.0915793	total: 3.05s	remaining: 2.4s
# 56:	learn: 0.0914010	total: 3.1s	remaining: 2.34s
# 57:	learn: 0.0910175	total: 3.15s	remaining: 2.28s
# 58:	learn: 0.0907946	total: 3.19s	remaining: 2.22s
# 59:	learn: 0.0904348	total: 3.23s	remaining: 2.15s
# 60:	learn: 0.0903617	total: 3.27s	remaining: 2.09s
# 61:	learn: 0.0898934	total: 3.32s	remaining: 2.03s
# 62:	learn: 0.0895998	total: 3.36s	remaining: 1.97s
# 63:	learn: 0.0894125	total: 3.41s	remaining: 1.92s
# 64:	learn: 0.0892579	total: 3.46s	remaining: 1.86s
# 65:	learn: 0.0889011	total: 3.5s	remaining: 1.8s
# 66:	learn: 0.0885538	total: 3.55s	remaining: 1.75s
# 67:	learn: 0.0882974	total: 3.6s	remaining: 1.7s
# 68:	learn: 0.0878383	total: 3.65s	remaining: 1.64s
# 69:	learn: 0.0874540	total: 3.69s	remaining: 1.58s
# 70:	learn: 0.0872345	total: 3.74s	remaining: 1.53s
# 71:	learn: 0.0871625	total: 3.78s	remaining: 1.47s
# 72:	learn: 0.0869950	total: 3.83s	remaining: 1.42s
# 73:	learn: 0.0868339	total: 3.87s	remaining: 1.36s
# 74:	learn: 0.0866539	total: 3.91s	remaining: 1.3s
# 75:	learn: 0.0859805	total: 3.95s	remaining: 1.25s
# 76:	learn: 0.0858332	total: 3.99s	remaining: 1.19s
# 77:	learn: 0.0856551	total: 4.02s	remaining: 1.14s
# 78:	learn: 0.0854380	total: 4.06s	remaining: 1.08s
# 79:	learn: 0.0852635	total: 4.11s	remaining: 1.03s
# 80:	learn: 0.0851386	total: 4.15s	remaining: 974ms
# 81:	learn: 0.0849642	total: 4.2s	remaining: 922ms
# 82:	learn: 0.0848365	total: 4.24s	remaining: 869ms
# 83:	learn: 0.0847033	total: 4.29s	remaining: 816ms
# 84:	learn: 0.0845524	total: 4.33s	remaining: 763ms
# 85:	learn: 0.0844041	total: 4.37s	remaining: 712ms
# 86:	learn: 0.0840285	total: 4.42s	remaining: 661ms
# 87:	learn: 0.0838110	total: 4.47s	remaining: 610ms
# 88:	learn: 0.0836647	total: 4.52s	remaining: 559ms
# 89:	learn: 0.0833411	total: 4.56s	remaining: 507ms
# 90:	learn: 0.0831172	total: 4.62s	remaining: 457ms
# 91:	learn: 0.0830234	total: 4.66s	remaining: 405ms
# 92:	learn: 0.0829405	total: 4.7s	remaining: 354ms
# 93:	learn: 0.0828622	total: 4.74s	remaining: 303ms
# 94:	learn: 0.0826288	total: 4.82s	remaining: 253ms
# 95:	learn: 0.0825176	total: 4.87s	remaining: 203ms
# 96:	learn: 0.0824354	total: 4.92s	remaining: 152ms
# 97:	learn: 0.0823334	total: 4.99s	remaining: 102ms
# 98:	learn: 0.0820842	total: 5.05s	remaining: 51ms
# 99:	learn: 0.0817928	total: 5.11s	remaining: 0us
# Accuracy Score of Cat Boost Classifier is : 0.9587311364336311
# Confusion Matrix :
# [[11345   459]
#  [  613 13559]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_cat = cohen_kappa_score(y_test, model_cat_prediction)
kappa_cat
# Out:
# 0.916861226494582

# %%
# Extra Trees Classifier
model_etc = ExtraTreesClassifier().fit(X_train, y_train)
model_etc_prediction = model_etc.predict(X_test)

accuracy_etc = accuracy_score(y_test, model_etc_prediction)
conf_etc = confusion_matrix(y_test, model_etc_prediction)
clf_report_etc = classification_report(y_test, model_etc_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_etc}")
print(f"Confusion Matrix : \n{conf_etc}")
print(f"Classification Report : \n{clf_report_etc}")
# Out:
# Accuracy Score of Cat Boost Classifier is : 0.9601940252540807
# Confusion Matrix :
# [[11388   416]
#  [  618 13554]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_etc = cohen_kappa_score(y_test, model_etc_prediction)
kappa_etc
# Out:
# 0.9198355144307143

# %%
# LGBM Classifier
model_lgbm = LGBMClassifier(learning_rate = 1).fit(X_train, y_train)
model_lgbm_prediction = model_lgbm.predict(X_test)

accuracy_lgbm = accuracy_score(y_test, model_lgbm_prediction)
conf_lgbm = confusion_matrix(y_test, model_lgbm_prediction)
clf_report_lgbm = classification_report(y_test, model_lgbm_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_lgbm}")
print(f"Confusion Matrix : \n{conf_lgbm}")
print(f"Classification Report : \n{clf_report_lgbm}")
# Out:
# Accuracy Score of Cat Boost Classifier is : 0.9355174006775485
# Confusion Matrix :
# [[10994   810]
#  [  865 13307]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93     11804
#            1       0.94      0.94      0.94     14172
#
#     accuracy                           0.94     25976
#    macro avg       0.93      0.94      0.94     25976
# weighted avg       0.94      0.94      0.94     25976

# %%
kappa_lgbm = cohen_kappa_score(y_test, model_lgbm_prediction)
kappa_lgbm
# Out:
# 0.870004679016504

# %%
# Voting Classifier
classifiers = [('Gradient Boosting Classifier', model_gb), ('Cat Boost Classifier', model_cat), ('XGboost', model_xgb),  
               ('Decision Tree', model_dt), ('Extra Tree', model_etc), ('Light Gradient', model_lgbm), ('Random Forest', model_rf), 
               ('Ada Boost', model_ada), ('Logistic', model_lr), ('Knn', model_knn)]
model_vc = VotingClassifier(estimators = classifiers).fit(X_train, y_train)
model_vc_prediction = model_vc.predict(X_test)

accuracy_vc = accuracy_score(y_test, model_vc_prediction)
conf_vc = confusion_matrix(y_test, model_vc_prediction)
clf_report_vc = classification_report(y_test, model_vc_prediction)

print(f"Accuracy Score of Voting Classifier is : {accuracy_vc}")
print(f"Confusion Matrix : \n{conf_vc}")
print(f"Classification Report : \n{clf_report_vc}")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.3579941	total: 40ms	remaining: 3.96s
# 1:	learn: 0.2655886	total: 79.1ms	remaining: 3.88s
# 2:	learn: 0.2148593	total: 123ms	remaining: 3.98s
# 3:	learn: 0.1924494	total: 164ms	remaining: 3.93s
# 4:	learn: 0.1819402	total: 206ms	remaining: 3.92s
# 5:	learn: 0.1699435	total: 252ms	remaining: 3.94s
# 6:	learn: 0.1632105	total: 300ms	remaining: 3.99s
# 7:	learn: 0.1574021	total: 352ms	remaining: 4.05s
# 8:	learn: 0.1555396	total: 396ms	remaining: 4s
# 9:	learn: 0.1532482	total: 441ms	remaining: 3.97s
# 10:	learn: 0.1508899	total: 490ms	remaining: 3.97s
# 11:	learn: 0.1474065	total: 535ms	remaining: 3.92s
# 12:	learn: 0.1403142	total: 579ms	remaining: 3.88s
# 13:	learn: 0.1387427	total: 623ms	remaining: 3.83s
# 14:	learn: 0.1356071	total: 671ms	remaining: 3.8s
# 15:	learn: 0.1333716	total: 732ms	remaining: 3.84s
# 16:	learn: 0.1319376	total: 804ms	remaining: 3.93s
# 17:	learn: 0.1296764	total: 864ms	remaining: 3.94s
# 18:	learn: 0.1256144	total: 920ms	remaining: 3.92s
# 19:	learn: 0.1242449	total: 975ms	remaining: 3.9s
# 20:	learn: 0.1231622	total: 1.04s	remaining: 3.92s
# 21:	learn: 0.1210017	total: 1.11s	remaining: 3.93s
# 22:	learn: 0.1198436	total: 1.16s	remaining: 3.89s
# 23:	learn: 0.1170150	total: 1.22s	remaining: 3.87s
# 24:	learn: 0.1148575	total: 1.28s	remaining: 3.84s
# 25:	learn: 0.1134539	total: 1.33s	remaining: 3.78s
# 26:	learn: 0.1127993	total: 1.38s	remaining: 3.72s
# 27:	learn: 0.1113738	total: 1.42s	remaining: 3.66s
# 28:	learn: 0.1097932	total: 1.47s	remaining: 3.59s
# 29:	learn: 0.1077473	total: 1.5s	remaining: 3.51s
# 30:	learn: 0.1061581	total: 1.55s	remaining: 3.45s
# 31:	learn: 0.1053008	total: 1.6s	remaining: 3.4s
# 32:	learn: 0.1045609	total: 1.65s	remaining: 3.34s
# 33:	learn: 0.1040806	total: 1.69s	remaining: 3.28s
# 34:	learn: 0.1034349	total: 1.73s	remaining: 3.21s
# 35:	learn: 0.1019287	total: 1.78s	remaining: 3.16s
# 36:	learn: 0.1008140	total: 1.82s	remaining: 3.1s
# 37:	learn: 0.1004271	total: 1.86s	remaining: 3.03s
# 38:	learn: 0.0998349	total: 1.91s	remaining: 2.99s
# 39:	learn: 0.0994602	total: 1.95s	remaining: 2.93s
# 40:	learn: 0.0986898	total: 2s	remaining: 2.87s
# 41:	learn: 0.0983351	total: 2.04s	remaining: 2.81s
# 42:	learn: 0.0974954	total: 2.09s	remaining: 2.77s
# 43:	learn: 0.0972606	total: 2.14s	remaining: 2.72s
# 44:	learn: 0.0968655	total: 2.2s	remaining: 2.69s
# 45:	learn: 0.0963943	total: 2.25s	remaining: 2.64s
# 46:	learn: 0.0959713	total: 2.3s	remaining: 2.6s
# 47:	learn: 0.0956220	total: 2.36s	remaining: 2.55s
# 48:	learn: 0.0953062	total: 2.4s	remaining: 2.5s
# 49:	learn: 0.0947707	total: 2.46s	remaining: 2.46s
# 50:	learn: 0.0941133	total: 2.51s	remaining: 2.41s
# 51:	learn: 0.0937078	total: 2.56s	remaining: 2.37s
# 52:	learn: 0.0934902	total: 2.62s	remaining: 2.33s
# 53:	learn: 0.0928423	total: 2.68s	remaining: 2.29s
# 54:	learn: 0.0920409	total: 2.74s	remaining: 2.25s
# 55:	learn: 0.0915793	total: 2.8s	remaining: 2.2s
# 56:	learn: 0.0914010	total: 2.85s	remaining: 2.15s
# 57:	learn: 0.0910175	total: 2.89s	remaining: 2.1s
# 58:	learn: 0.0907946	total: 2.94s	remaining: 2.04s
# 59:	learn: 0.0904348	total: 2.98s	remaining: 1.99s
# 60:	learn: 0.0903617	total: 3.02s	remaining: 1.93s
# 61:	learn: 0.0898934	total: 3.07s	remaining: 1.88s
# 62:	learn: 0.0895998	total: 3.12s	remaining: 1.83s
# 63:	learn: 0.0894125	total: 3.16s	remaining: 1.78s
# 64:	learn: 0.0892579	total: 3.2s	remaining: 1.72s
# 65:	learn: 0.0889011	total: 3.24s	remaining: 1.67s
# 66:	learn: 0.0885538	total: 3.28s	remaining: 1.62s
# 67:	learn: 0.0882974	total: 3.35s	remaining: 1.57s
# 68:	learn: 0.0878383	total: 3.39s	remaining: 1.52s
# 69:	learn: 0.0874540	total: 3.44s	remaining: 1.48s
# 70:	learn: 0.0872345	total: 3.49s	remaining: 1.42s
# 71:	learn: 0.0871625	total: 3.53s	remaining: 1.37s
# 72:	learn: 0.0869950	total: 3.6s	remaining: 1.33s
# 73:	learn: 0.0868339	total: 3.65s	remaining: 1.28s
# 74:	learn: 0.0866539	total: 3.71s	remaining: 1.24s
# 75:	learn: 0.0859805	total: 3.78s	remaining: 1.19s
# 76:	learn: 0.0858332	total: 3.83s	remaining: 1.14s
# 77:	learn: 0.0856551	total: 3.89s	remaining: 1.1s
# 78:	learn: 0.0854380	total: 3.95s	remaining: 1.05s
# 79:	learn: 0.0852635	total: 4s	remaining: 1000ms
# 80:	learn: 0.0851386	total: 4.04s	remaining: 949ms
# 81:	learn: 0.0849642	total: 4.09s	remaining: 898ms
# 82:	learn: 0.0848365	total: 4.13s	remaining: 846ms
# 83:	learn: 0.0847033	total: 4.17s	remaining: 795ms
# 84:	learn: 0.0845524	total: 4.22s	remaining: 745ms
# 85:	learn: 0.0844041	total: 4.27s	remaining: 695ms
# 86:	learn: 0.0840285	total: 4.31s	remaining: 644ms
# 87:	learn: 0.0838110	total: 4.34s	remaining: 593ms
# 88:	learn: 0.0836647	total: 4.38s	remaining: 541ms
# 89:	learn: 0.0833411	total: 4.48s	remaining: 497ms
# 90:	learn: 0.0831172	total: 4.51s	remaining: 446ms
# 91:	learn: 0.0830234	total: 4.55s	remaining: 395ms
# 92:	learn: 0.0829405	total: 4.58s	remaining: 345ms
# 93:	learn: 0.0828622	total: 4.63s	remaining: 296ms
# 94:	learn: 0.0826288	total: 4.67s	remaining: 246ms
# 95:	learn: 0.0825176	total: 4.71s	remaining: 196ms
# 96:	learn: 0.0824354	total: 4.75s	remaining: 147ms
# 97:	learn: 0.0823334	total: 4.81s	remaining: 98.1ms
# 98:	learn: 0.0820842	total: 4.85s	remaining: 49ms
# 99:	learn: 0.0817928	total: 4.89s	remaining: 0us
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:48:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy Score of Voting Classifier is : 0.9574992300585156
# Confusion Matrix :
# [[11396   408]
#  [  696 13476]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     11804
#            1       0.97      0.95      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_vc = cohen_kappa_score(y_test, model_vc_prediction)
kappa_vc
# Out:
# 0.9144605102463036

# %%
# Models Comparison
models = pd.DataFrame({
    'Model' : ['Logistic Regression', 'KNN', 'Decision Tree Classifier', 'Random Forest Classifier','Ada Boost Classifier',
             'Gradient Boosting Classifier', 'XgBoost', 'Cat Boost', 'Extra Trees Classifier', 'LGBM', 'Voting Classifier', 'K-Fold Decision Tree'],
    'Score' : [accuracy_lr, accuracy_knn, accuracy_dt, accuracy_rf, accuracy_ada, accuracy_gb, accuracy_xgb, accuracy_cat, 
              accuracy_etc, accuracy_lgbm, accuracy_vc, model_kfdt.mean()],
    'Kappa' : [kappa_lr, kappa_knn, kappa_dt, kappa_rf, kappa_ada, kappa_gb, kappa_xgb, kappa_cat, kappa_etc, kappa_lgbm, 
              kappa_vc, model_kfdt.mean()]
})

# Sorting the results by Kappa values
models_sorted = models.sort_values(by = 'Kappa', ascending = False)
models_sorted.reset_index(drop = True, inplace = True)
models_sorted
# Out:
#                            Model     Score     Kappa
# 0       Random Forest Classifier  0.960579  0.920637
# 1         Extra Trees Classifier  0.960194  0.919836
# 2                      Cat Boost  0.958731  0.916861
# 3              Voting Classifier  0.957499  0.914461
# 4                        XgBoost  0.956421  0.912215
# 5           K-Fold Decision Tree  0.910373  0.910373
# 6       Decision Tree Classifier  0.941908  0.882810
# 7                           LGBM  0.935517  0.870005
# 8                            KNN  0.930320  0.859976
# 9   Gradient Boosting Classifier  0.926702  0.852160
# 10          Ada Boost Classifier  0.905451  0.809463
# 11           Logistic Regression  0.837889  0.672845

# %%
# PLOT: All Kappa values as comparison

plt.bar(x=models_sorted.Model, height = models_sorted.Kappa, color = 'c', width = 0.5)
#plt.grid()
plt.title('Machine Learning Models in Prediction of Airline Passenger`s Satisfaction')
plt.xlabel('Exploration Methods', fontsize=15)
plt.ylabel('Kappa', fontsize=15)
plt.ylim(0, 1)
plt.xticks(rotation=90)
plt.rcParams['figure.figsize'] = [5, 8]

for i in models_sorted.index:
  plt.text(x = i, 
           y = models_sorted.Kappa[i], 
           s = round(models_sorted.Kappa[i], 3), 
           horizontalalignment='center',
           verticalalignment='bottom',
           size = 11)

plt.show()
