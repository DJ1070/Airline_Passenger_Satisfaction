# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, cohen_kappa_score
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from imblearn.over_sampling import RandomOverSampler

# %%
df = pd.read_excel('./Data/satisfaction.xlsx')

# %%
df
# Out:
#             id          satisfaction_v2  Gender      Customer Type  Age  \
# 0        11112                satisfied  Female     Loyal Customer   65
# 1       110278                satisfied    Male     Loyal Customer   47
# 2       103199                satisfied  Female     Loyal Customer   15
# 3        47462                satisfied  Female     Loyal Customer   60
# 4       120011                satisfied  Female     Loyal Customer   70
# ...        ...                      ...     ...                ...  ...
# 129875  119211                satisfied  Female  disloyal Customer   29
# 129876   97768  neutral or dissatisfied    Male  disloyal Customer   63
# 129877  125368  neutral or dissatisfied    Male  disloyal Customer   69
# 129878     251  neutral or dissatisfied    Male  disloyal Customer   66
# 129879   84566  neutral or dissatisfied  Female  disloyal Customer   38
#
#          Type of Travel     Class  Flight Distance  Seat comfort  \
# 0       Personal Travel       Eco              265             0
# 1       Personal Travel  Business             2464             0
# 2       Personal Travel       Eco             2138             0
# 3       Personal Travel       Eco              623             0
# 4       Personal Travel       Eco              354             0
# ...                 ...       ...              ...           ...
# 129875  Personal Travel       Eco             1731             5
# 129876  Personal Travel  Business             2087             2
# 129877  Personal Travel       Eco             2320             3
# 129878  Personal Travel       Eco             2450             3
# 129879  Personal Travel       Eco             4307             3
#
#         Departure/Arrival time convenient  ...  Online support  \
# 0                                       0  ...               2
# 1                                       0  ...               2
# 2                                       0  ...               2
# 3                                       0  ...               3
# 4                                       0  ...               4
# ...                                   ...  ...             ...
# 129875                                  5  ...               2
# 129876                                  3  ...               1
# 129877                                  0  ...               2
# 129878                                  2  ...               2
# 129879                                  4  ...               3
#
#         Ease of Online booking  On-board service  Leg room service  \
# 0                            3                 3                 0
# 1                            3                 4                 4
# 2                            2                 3                 3
# 3                            1                 1                 0
# 4                            2                 2                 0
# ...                        ...               ...               ...
# 129875                       2                 3                 3
# 129876                       3                 2                 3
# 129877                       4                 4                 3
# 129878                       3                 3                 2
# 129879                       4                 5                 5
#
#         Baggage handling  Checkin service  Cleanliness  Online boarding  \
# 0                      3                5            3                2
# 1                      4                2            3                2
# 2                      4                4            4                2
# 3                      1                4            1                3
# 4                      2                4            2                5
# ...                  ...              ...          ...              ...
# 129875                 4                4            4                2
# 129876                 3                1            2                1
# 129877                 4                2            3                2
# 129878                 3                2            1                2
# 129879                 5                3            3                3
#
#         Departure Delay in Minutes  Arrival Delay in Minutes
# 0                                0                       0.0
# 1                              310                     305.0
# 2                                0                       0.0
# 3                                0                       0.0
# 4                                0                       0.0
# ...                            ...                       ...
# 129875                           0                       0.0
# 129876                         174                     172.0
# 129877                         155                     163.0
# 129878                         193                     205.0
# 129879                         185                     186.0
#
# [129880 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['id', 'satisfaction_v2', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
df.columns = ['ID', 'Satisfaction', 'Gender', 'Customer_type', 'Age',
       'Type_of_travel', 'Class', 'Flight_distance', 'Seat_comfort',
       'Departure_arrival_time_convenient', 'Food_and_drink', 'Gate_location',
       'Inflight_wifi_service', 'Inflight_entertainment', 'Online_support',
       'Ease_of_online_booking', 'Onboard_service', 'Leg_room_service',
       'Baggage_handling', 'Checkin_service', 'Cleanliness', 'Online_boarding',
       'Departure_delay_in_minutes', 'Arrival_delay_in_minutes']

# %%
df['Satisfaction'] = df['Satisfaction'].apply(lambda value: 1 
if value == 'satisfied' else 0)

# %%
df['Gender'] = df['Gender'].apply(lambda value: 1 
if value == 'Female' else 0)

# %%
df['Customer_type'] = df['Customer_type'].apply(lambda value: 1 
if value == 'Loyal Customer' else 0)

# %%
df['Type_of_travel'] = df['Type_of_travel'].apply(lambda value: 1 
if value == 'Business travel' else 0)

# %%
df['Class'] = df['Class'].apply(lambda value: 0 
if value == 'Eco' else 1
if value == 'Eco Plus' else 2)

# %%
df.dtypes
# Out:
# ID                                     int64
# Satisfaction                           int64
# Gender                                 int64
# Customer_type                          int64
# Age                                    int64
# Type_of_travel                         int64
# Class                                  int64
# Flight_distance                        int64
# Seat_comfort                           int64
# Departure_arrival_time_convenient      int64
# Food_and_drink                         int64
# Gate_location                          int64
# Inflight_wifi_service                  int64
# Inflight_entertainment                 int64
# Online_support                         int64
# Ease_of_online_booking                 int64
# Onboard_service                        int64
# Leg_room_service                       int64
# Baggage_handling                       int64
# Checkin_service                        int64
# Cleanliness                            int64
# Online_boarding                        int64
# Departure_delay_in_minutes             int64
# Arrival_delay_in_minutes             float64
# dtype: object

# %%
df = df.drop(['ID', 'Gate_location', 'Departure_delay_in_minutes'], axis = 1)

# %%
df
# Out:
#         Satisfaction  Gender  Customer_type  Age  Type_of_travel  Class  \
# 0                  1       1              1   65               0      0
# 1                  1       0              1   47               0      2
# 2                  1       1              1   15               0      0
# 3                  1       1              1   60               0      0
# 4                  1       1              1   70               0      0
# ...              ...     ...            ...  ...             ...    ...
# 129875             1       1              0   29               0      0
# 129876             0       0              0   63               0      2
# 129877             0       0              0   69               0      0
# 129878             0       0              0   66               0      0
# 129879             0       1              0   38               0      0
#
#         Flight_distance  Seat_comfort  Departure_arrival_time_convenient  \
# 0                   265             0                                  0
# 1                  2464             0                                  0
# 2                  2138             0                                  0
# 3                   623             0                                  0
# 4                   354             0                                  0
# ...                 ...           ...                                ...
# 129875             1731             5                                  5
# 129876             2087             2                                  3
# 129877             2320             3                                  0
# 129878             2450             3                                  2
# 129879             4307             3                                  4
#
#         Food_and_drink  ...  Inflight_entertainment  Online_support  \
# 0                    0  ...                       4               2
# 1                    0  ...                       2               2
# 2                    0  ...                       0               2
# 3                    0  ...                       4               3
# 4                    0  ...                       3               4
# ...                ...  ...                     ...             ...
# 129875               5  ...                       5               2
# 129876               2  ...                       1               1
# 129877               3  ...                       2               2
# 129878               3  ...                       2               2
# 129879               3  ...                       3               3
#
#         Ease_of_online_booking  Onboard_service  Leg_room_service  \
# 0                            3                3                 0
# 1                            3                4                 4
# 2                            2                3                 3
# 3                            1                1                 0
# 4                            2                2                 0
# ...                        ...              ...               ...
# 129875                       2                3                 3
# 129876                       3                2                 3
# 129877                       4                4                 3
# 129878                       3                3                 2
# 129879                       4                5                 5
#
#         Baggage_handling  Checkin_service  Cleanliness  Online_boarding  \
# 0                      3                5            3                2
# 1                      4                2            3                2
# 2                      4                4            4                2
# 3                      1                4            1                3
# 4                      2                4            2                5
# ...                  ...              ...          ...              ...
# 129875                 4                4            4                2
# 129876                 3                1            2                1
# 129877                 4                2            3                2
# 129878                 3                2            1                2
# 129879                 5                3            3                3
#
#         Arrival_delay_in_minutes
# 0                            0.0
# 1                          305.0
# 2                            0.0
# 3                            0.0
# 4                            0.0
# ...                          ...
# 129875                       0.0
# 129876                     172.0
# 129877                     163.0
# 129878                     205.0
# 129879                     186.0
#
# [129880 rows x 21 columns]

# %%
df[df.Arrival_delay_in_minutes.isna() == True]
# Out:
#         Satisfaction  Gender  Customer_type  Age  Type_of_travel  Class  \
# 145                1       1              1   21               0      0
# 246                1       0              1   28               0      0
# 710                1       0              1   28               0      0
# 736                1       0              1    9               0      0
# 818                0       0              1    9               0      0
# ...              ...     ...            ...  ...             ...    ...
# 127739             1       0              1   44               1      2
# 128131             1       0              1   39               1      2
# 128710             1       1              1   45               1      0
# 129774             1       0              0   49               0      0
# 129873             1       1              0   63               0      0
#
#         Flight_distance  Seat_comfort  Departure_arrival_time_convenient  \
# 145                4804             0                                  2
# 246                1364             0                                  3
# 710                1792             0                                  5
# 736                1862             0                                  5
# 818                1668             1                                  0
# ...                 ...           ...                                ...
# 127739             3431             2                                  2
# 128131             1595             4                                  4
# 128710              871             5                                  1
# 129774             1594             5                                  4
# 129873             1942             5                                  5
#
#         Food_and_drink  ...  Inflight_entertainment  Online_support  \
# 145                  0  ...                       0               5
# 246                  0  ...                       0               4
# 710                  0  ...                       0               5
# 736                  0  ...                       0               3
# 818                  1  ...                       1               4
# ...                ...  ...                     ...             ...
# 127739               3  ...                       2               4
# 128131               4  ...                       4               5
# 128710               1  ...                       5               2
# 129774               5  ...                       5               3
# 129873               4  ...                       4               3
#
#         Ease_of_online_booking  Onboard_service  Leg_room_service  \
# 145                          5                4                 1
# 246                          2                1                 1
# 710                          5                4                 4
# 736                          3                5                 3
# 818                          4                4                 5
# ...                        ...              ...               ...
# 127739                       5                5                 5
# 128131                       5                5                 5
# 128710                       5                5                 5
# 129774                       3                1                 4
# 129873                       3                5                 2
#
#         Baggage_handling  Checkin_service  Cleanliness  Online_boarding  \
# 145                    4                2            3                5
# 246                    3                4            3                2
# 710                    5                3            4                5
# 736                    4                4            4                3
# 818                    1                5            1                4
# ...                  ...              ...          ...              ...
# 127739                 5                5            5                4
# 128131                 5                3            5                5
# 128710                 5                1            5                5
# 129774                 3                3            4                3
# 129873                 5                3            5                3
#
#         Arrival_delay_in_minutes
# 145                          NaN
# 246                          NaN
# 710                          NaN
# 736                          NaN
# 818                          NaN
# ...                          ...
# 127739                       NaN
# 128131                       NaN
# 128710                       NaN
# 129774                       NaN
# 129873                       NaN
#
# [393 rows x 21 columns]

# %%
df.Arrival_delay_in_minutes = df.Arrival_delay_in_minutes.fillna(df.Arrival_delay_in_minutes.mean())

# %%
fig, ax = plt.subplots(figsize=(24, 16)) 
sns.heatmap(df.corr(), annot=True, ax = ax)
# Out:
# <AxesSubplot:>

# %%
X = df.iloc[:,1:]
y = np.array(df['Satisfaction'])

X_scaled = StandardScaler().fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=1)

# %%
# Logistic Regression
model_lr = LogisticRegression().fit(X_train, y_train)
model_lr_prediction = model_lr.predict(X_test)
accuracy_lr = accuracy_score(y_test, model_lr_prediction)

conf_lr = confusion_matrix(y_test, model_lr_prediction)
clf_report_lr = classification_report(y_test, model_lr_prediction)

print(f"Accuracy Score of Logistic Regression is : {accuracy_lr}")
print(f"Confusion Matrix : \n{conf_lr}")
print(f"Classification Report : \n{clf_report_lr}")
# Out:
# Accuracy Score of Logistic Regression is : 0.8375423467816446
# Confusion Matrix :
# [[ 9650  2154]
#  [ 2066 12106]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82     11804
#            1       0.85      0.85      0.85     14172
#
#     accuracy                           0.84     25976
#    macro avg       0.84      0.84      0.84     25976
# weighted avg       0.84      0.84      0.84     25976

# %%
kappa_lr = cohen_kappa_score(y_test, model_lr_prediction)
kappa_lr
# Out:
# 0.6721577171756479

# %%
# Decision Tree
model_dt = tree.DecisionTreeClassifier().fit(X_train, y_train)
model_dt_prediction = model_dt.predict(X_test)
accuracy_dt = accuracy_score(y_test, model_dt_prediction)

conf_dt = confusion_matrix(y_test, model_dt_prediction)
clf_report_dt = classification_report(y_test, model_dt_prediction)

print(f"Accuracy Score of Decision Tree is : {accuracy_dt}")
print(f"Confusion Matrix : \n{conf_dt}")
print(f"Classification Report : \n{clf_report_dt}")
# Out:
# Accuracy Score of Decision Tree is : 0.9405605174006776
# Confusion Matrix :
# [[11020   784]
#  [  760 13412]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93     11804
#            1       0.94      0.95      0.95     14172
#
#     accuracy                           0.94     25976
#    macro avg       0.94      0.94      0.94     25976
# weighted avg       0.94      0.94      0.94     25976

# %%
kappa_dt = cohen_kappa_score(y_test, model_dt_prediction)
kappa_dt
# Out:
# 0.880104465277425

# %%
# K-Fold DecisionTree
model_kfdt = cross_val_score(tree.DecisionTreeClassifier(max_depth = 7), X, y, cv=700)
print('Maximum: ', model_kfdt.max())
print('Mean: ', model_kfdt.mean())

model_kfdt = pd.Series(model_kfdt)
model_kfdt.plot()
# Out:
# Maximum:  1.0
# Mean:  0.9094650226263129
# <AxesSubplot:>

# %%
# KNN
model_knn = KNeighborsClassifier(n_neighbors = 7, metric = 'minkowski', p = 2).fit(X_train, y_train)
model_knn_prediction = model_knn.predict(X_test)
accuracy_knn = accuracy_score(y_test, model_knn_prediction)

conf_knn = confusion_matrix(y_test, model_knn_prediction)
clf_report_knn = classification_report(y_test, model_knn_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_knn}")
print(f"Confusion Matrix : \n{conf_knn}")
print(f"Classification Report : \n{clf_report_knn}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.9294348629504158
# Confusion Matrix :
# [[11154   650]
#  [ 1183 12989]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92     11804
#            1       0.95      0.92      0.93     14172
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
kappa_knn = cohen_kappa_score(y_test, model_knn_prediction)
kappa_knn
# Out:
# 0.8582219015353743

# %%
# Random Forest Classifier
model_rf = RandomForestClassifier(n_estimators=1500, criterion = 'entropy', random_state = 6).fit(X_train, y_train)
model_rf_prediction = model_rf.predict(X_test)
rf = accuracy_score(y_test, model_rf_prediction)
print('Accuracy Score: ', rf)
# Out:
# Accuracy Score:  0.959809054511857

# %%
kappa_rf = cohen_kappa_score(y_test, model_rf_prediction)
print('Kappa: ', kappa_rf)
# Out:
# Kappa:  0.9190785306838947

# %%
# Random Forest
model_rf = RandomForestClassifier(n_estimators=1500).fit(X_train, y_train)
model_rf_prediction = model_rf.predict(X_test)
accuracy_rf = accuracy_score(y_test, model_rf_prediction)

conf_rf = confusion_matrix(y_test, model_rf_prediction)
clf_report_rf = classification_report(y_test, model_rf_prediction)

print(f"Accuracy Score of Random Forest is : {accuracy_rf}")
print(f"Confusion Matrix : \n{conf_rf}")
print(f"Classification Report : \n{clf_report_rf}")
# Out:
# Accuracy Score of Random Forest is : 0.9599245457345241
# Confusion Matrix :
# [[11391   413]
#  [  628 13544]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_rf = cohen_kappa_score(y_test, model_rf_prediction)
kappa_rf
# Out:
# 0.9193002293983853

# %%
# Ada Boost
model_ada = AdaBoostClassifier(n_estimators = 1000).fit(X_train, y_train)
model_ada_prediction = model_ada.predict(X_test)
accuracy_ada = accuracy_score(y_test, model_ada_prediction)

conf_ada = confusion_matrix(y_test, model_ada_prediction)
clf_report_ada = classification_report(y_test, model_ada_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_ada}")
print(f"Confusion Matrix : \n{conf_ada}")
print(f"Classification Report : \n{clf_report_ada}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.9058361564521097
# Confusion Matrix :
# [[10644  1160]
#  [ 1286 12886]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90     11804
#            1       0.92      0.91      0.91     14172
#
#     accuracy                           0.91     25976
#    macro avg       0.90      0.91      0.91     25976
# weighted avg       0.91      0.91      0.91     25976

# %%
kappa_ada = cohen_kappa_score(y_test, model_ada_prediction)
kappa_ada
# Out:
# 0.8102633353582328

# %%
# Gradient Boosting Classifier
model_gb = GradientBoostingClassifier().fit(X_train, y_train)
model_gb_prediction = model_gb.predict(X_test)

accuracy_gb = accuracy_score(y_test, model_gb_prediction)
conf_gb = confusion_matrix(y_test, model_gb_prediction)
clf_report_gb = classification_report(y_test, model_gb_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_gb}")
print(f"Confusion Matrix : \n{conf_gb}")
print(f"Classification Report : \n{clf_report_gb}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.9263165999384047
# Confusion Matrix :
# [[10844   960]
#  [  954 13218]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     11804
#            1       0.93      0.93      0.93     14172
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
kappa_gb = cohen_kappa_score(y_test, model_gb_prediction)
kappa_gb
# Out:
# 0.8513919580095513

# %%
# XgBoost Classifier
model_xgb = XGBClassifier(booster = 'gbtree', learning_rate = 0.1, max_depth = 5, n_estimators = 180).fit(X_train, y_train)
model_xgb_prediction = model_xgb.predict(X_test)

accuracy_xgb = accuracy_score(y_test, model_xgb_prediction)
conf_xgb = confusion_matrix(y_test, model_xgb_prediction)
clf_report_xgb = classification_report(y_test, model_xgb_prediction)

print(f"Accuracy Score of XgBoost Classifier is : {accuracy_xgb}")
print(f"Confusion Matrix : \n{conf_xgb}")
print(f"Classification Report : \n{clf_report_xgb}")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:12:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy Score of XgBoost Classifier is : 0.954111487526948
# Confusion Matrix :
# [[11283   521]
#  [  671 13501]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     11804
#            1       0.96      0.95      0.96     14172
#
#     accuracy                           0.95     25976
#    macro avg       0.95      0.95      0.95     25976
# weighted avg       0.95      0.95      0.95     25976

# %%
kappa_xgb = cohen_kappa_score(y_test, model_xgb_prediction)
kappa_xgb
# Out:
# 0.9075520329493365

# %%
# Cat Boost Classifier
model_cat = CatBoostClassifier(iterations=100).fit(X_train, y_train)
model_cat_prediction = model_cat.predict(X_test)

accuracy_cat = accuracy_score(y_test, model_cat_prediction)
conf_cat = confusion_matrix(y_test, model_cat_prediction)
clf_report_cat = classification_report(y_test, model_cat_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_cat}")
print(f"Confusion Matrix : \n{conf_cat}")
print(f"Classification Report : \n{clf_report_cat}")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.3436023	total: 194ms	remaining: 19.2s
# 1:	learn: 0.2592482	total: 239ms	remaining: 11.7s
# 2:	learn: 0.2167672	total: 286ms	remaining: 9.23s
# 3:	learn: 0.1944419	total: 329ms	remaining: 7.88s
# 4:	learn: 0.1832766	total: 376ms	remaining: 7.15s
# 5:	learn: 0.1668958	total: 422ms	remaining: 6.61s
# 6:	learn: 0.1588808	total: 474ms	remaining: 6.3s
# 7:	learn: 0.1528589	total: 529ms	remaining: 6.08s
# 8:	learn: 0.1450445	total: 574ms	remaining: 5.81s
# 9:	learn: 0.1435430	total: 616ms	remaining: 5.54s
# 10:	learn: 0.1405705	total: 664ms	remaining: 5.37s
# 11:	learn: 0.1394585	total: 716ms	remaining: 5.25s
# 12:	learn: 0.1372860	total: 767ms	remaining: 5.13s
# 13:	learn: 0.1338752	total: 815ms	remaining: 5s
# 14:	learn: 0.1314075	total: 877ms	remaining: 4.97s
# 15:	learn: 0.1297645	total: 928ms	remaining: 4.87s
# 16:	learn: 0.1284126	total: 984ms	remaining: 4.8s
# 17:	learn: 0.1262739	total: 1.03s	remaining: 4.72s
# 18:	learn: 0.1253170	total: 1.09s	remaining: 4.65s
# 19:	learn: 0.1230202	total: 1.16s	remaining: 4.63s
# 20:	learn: 0.1204183	total: 1.22s	remaining: 4.58s
# 21:	learn: 0.1160168	total: 1.29s	remaining: 4.59s
# 22:	learn: 0.1143964	total: 1.36s	remaining: 4.57s
# 23:	learn: 0.1137244	total: 1.46s	remaining: 4.64s
# 24:	learn: 0.1127004	total: 1.57s	remaining: 4.72s
# 25:	learn: 0.1118192	total: 1.69s	remaining: 4.82s
# 26:	learn: 0.1108499	total: 1.81s	remaining: 4.89s
# 27:	learn: 0.1097165	total: 1.89s	remaining: 4.87s
# 28:	learn: 0.1086238	total: 1.96s	remaining: 4.81s
# 29:	learn: 0.1078026	total: 2.02s	remaining: 4.72s
# 30:	learn: 0.1062136	total: 2.09s	remaining: 4.66s
# 31:	learn: 0.1055353	total: 2.16s	remaining: 4.6s
# 32:	learn: 0.1050315	total: 2.21s	remaining: 4.5s
# 33:	learn: 0.1047193	total: 2.28s	remaining: 4.42s
# 34:	learn: 0.1040732	total: 2.36s	remaining: 4.38s
# 35:	learn: 0.1034673	total: 2.43s	remaining: 4.32s
# 36:	learn: 0.1027583	total: 2.5s	remaining: 4.26s
# 37:	learn: 0.1021503	total: 2.56s	remaining: 4.18s
# 38:	learn: 0.1009945	total: 2.62s	remaining: 4.1s
# 39:	learn: 0.1004105	total: 2.68s	remaining: 4.03s
# 40:	learn: 0.0997307	total: 2.75s	remaining: 3.96s
# 41:	learn: 0.0992269	total: 2.81s	remaining: 3.89s
# 42:	learn: 0.0980505	total: 2.88s	remaining: 3.82s
# 43:	learn: 0.0976982	total: 2.94s	remaining: 3.74s
# 44:	learn: 0.0974164	total: 3s	remaining: 3.66s
# 45:	learn: 0.0969450	total: 3.05s	remaining: 3.58s
# 46:	learn: 0.0967569	total: 3.1s	remaining: 3.5s
# 47:	learn: 0.0953902	total: 3.15s	remaining: 3.42s
# 48:	learn: 0.0948347	total: 3.21s	remaining: 3.34s
# 49:	learn: 0.0943834	total: 3.26s	remaining: 3.26s
# 50:	learn: 0.0939689	total: 3.31s	remaining: 3.18s
# 51:	learn: 0.0935512	total: 3.36s	remaining: 3.1s
# 52:	learn: 0.0932172	total: 3.42s	remaining: 3.03s
# 53:	learn: 0.0929559	total: 3.47s	remaining: 2.95s
# 54:	learn: 0.0927413	total: 3.52s	remaining: 2.88s
# 55:	learn: 0.0925428	total: 3.56s	remaining: 2.8s
# 56:	learn: 0.0923962	total: 3.62s	remaining: 2.73s
# 57:	learn: 0.0921232	total: 3.67s	remaining: 2.66s
# 58:	learn: 0.0912500	total: 3.73s	remaining: 2.59s
# 59:	learn: 0.0909505	total: 3.79s	remaining: 2.53s
# 60:	learn: 0.0906517	total: 3.84s	remaining: 2.45s
# 61:	learn: 0.0904037	total: 3.88s	remaining: 2.38s
# 62:	learn: 0.0901206	total: 3.93s	remaining: 2.31s
# 63:	learn: 0.0896290	total: 3.98s	remaining: 2.24s
# 64:	learn: 0.0894460	total: 4.04s	remaining: 2.18s
# 65:	learn: 0.0891672	total: 4.09s	remaining: 2.11s
# 66:	learn: 0.0887993	total: 4.15s	remaining: 2.04s
# 67:	learn: 0.0879560	total: 4.21s	remaining: 1.98s
# 68:	learn: 0.0878063	total: 4.26s	remaining: 1.91s
# 69:	learn: 0.0877326	total: 4.3s	remaining: 1.84s
# 70:	learn: 0.0876015	total: 4.35s	remaining: 1.78s
# 71:	learn: 0.0873453	total: 4.42s	remaining: 1.72s
# 72:	learn: 0.0869830	total: 4.48s	remaining: 1.66s
# 73:	learn: 0.0868232	total: 4.54s	remaining: 1.59s
# 74:	learn: 0.0866781	total: 4.6s	remaining: 1.53s
# 75:	learn: 0.0861234	total: 4.67s	remaining: 1.48s
# 76:	learn: 0.0859058	total: 4.74s	remaining: 1.41s
# 77:	learn: 0.0858029	total: 4.79s	remaining: 1.35s
# 78:	learn: 0.0855793	total: 4.86s	remaining: 1.29s
# 79:	learn: 0.0853771	total: 4.92s	remaining: 1.23s
# 80:	learn: 0.0850007	total: 5s	remaining: 1.17s
# 81:	learn: 0.0849015	total: 5.06s	remaining: 1.11s
# 82:	learn: 0.0847148	total: 5.11s	remaining: 1.05s
# 83:	learn: 0.0844650	total: 5.16s	remaining: 982ms
# 84:	learn: 0.0842966	total: 5.21s	remaining: 919ms
# 85:	learn: 0.0841451	total: 5.25s	remaining: 856ms
# 86:	learn: 0.0840163	total: 5.31s	remaining: 793ms
# 87:	learn: 0.0838309	total: 5.36s	remaining: 731ms
# 88:	learn: 0.0837296	total: 5.4s	remaining: 668ms
# 89:	learn: 0.0836237	total: 5.46s	remaining: 606ms
# 90:	learn: 0.0834898	total: 5.5s	remaining: 544ms
# 91:	learn: 0.0832619	total: 5.54s	remaining: 482ms
# 92:	learn: 0.0831588	total: 5.59s	remaining: 421ms
# 93:	learn: 0.0828996	total: 5.65s	remaining: 361ms
# 94:	learn: 0.0825747	total: 5.7s	remaining: 300ms
# 95:	learn: 0.0821255	total: 5.75s	remaining: 239ms
# 96:	learn: 0.0819448	total: 5.8s	remaining: 179ms
# 97:	learn: 0.0817133	total: 5.87s	remaining: 120ms
# 98:	learn: 0.0816302	total: 5.92s	remaining: 59.8ms
# 99:	learn: 0.0814453	total: 5.96s	remaining: 0us
# Accuracy Score of Cat Boost Classifier is : 0.9585001539882969
# Confusion Matrix :
# [[11342   462]
#  [  616 13556]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_cat = cohen_kappa_score(y_test, model_cat_prediction)
kappa_cat
# Out:
# 0.916395897538395

# %%
# Extra Trees Classifier
model_etc = ExtraTreesClassifier().fit(X_train, y_train)
model_etc_prediction = model_etc.predict(X_test)

accuracy_etc = accuracy_score(y_test, model_etc_prediction)
conf_etc = confusion_matrix(y_test, model_etc_prediction)
clf_report_etc = classification_report(y_test, model_etc_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_etc}")
print(f"Confusion Matrix : \n{conf_etc}")
print(f"Classification Report : \n{clf_report_etc}")
# Out:
# Accuracy Score of Cat Boost Classifier is : 0.9595395749923006
# Confusion Matrix :
# [[11381   423]
#  [  628 13544]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_etc = cohen_kappa_score(y_test, model_etc_prediction)
kappa_etc
# Out:
# 0.9185192572739402

# %%
# LGBM Classifier
model_lgbm = LGBMClassifier(learning_rate = 1).fit(X_train, y_train)
model_lgbm_prediction = model_lgbm.predict(X_test)

accuracy_lgbm = accuracy_score(y_test, model_lgbm_prediction)
conf_lgbm = confusion_matrix(y_test, model_lgbm_prediction)
clf_report_lgbm = classification_report(y_test, model_lgbm_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_lgbm}")
print(f"Confusion Matrix : \n{conf_lgbm}")
print(f"Classification Report : \n{clf_report_lgbm}")
# Out:
# Accuracy Score of Cat Boost Classifier is : 0.9072605481983369
# Confusion Matrix :
# [[10611  1193]
#  [ 1216 12956]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90     11804
#            1       0.92      0.91      0.91     14172
#
#     accuracy                           0.91     25976
#    macro avg       0.91      0.91      0.91     25976
# weighted avg       0.91      0.91      0.91     25976

# %%
kappa_lgbm = cohen_kappa_score(y_test, model_lgbm_prediction)
kappa_lgbm
# Out:
# 0.8129972281976974

# %%
# Voting Classifier
classifiers = [('Gradient Boosting Classifier', model_gb), ('Cat Boost Classifier', model_cat), ('XGboost', model_xgb),  
               ('Decision Tree', model_dt), ('Extra Tree', model_etc), ('Light Gradient', model_lgbm), ('Random Forest', model_rf), 
               ('Ada Boost', model_ada), ('Logistic', model_lr), ('Knn', model_knn)]
model_vc = VotingClassifier(estimators = classifiers).fit(X_train, y_train)
model_vc_prediction = model_vc.predict(X_test)

accuracy_vc = accuracy_score(y_test, model_vc_prediction)
conf_vc = confusion_matrix(y_test, model_vc_prediction)
clf_report_vc = classification_report(y_test, model_vc_prediction)

print(f"Accuracy Score of Voting Classifier is : {accuracy_vc}")
print(f"Confusion Matrix : \n{conf_vc}")
print(f"Classification Report : \n{clf_report_vc}")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.3436023	total: 42.9ms	remaining: 4.24s
# 1:	learn: 0.2592482	total: 91.6ms	remaining: 4.49s
# 2:	learn: 0.2167672	total: 138ms	remaining: 4.47s
# 3:	learn: 0.1944419	total: 179ms	remaining: 4.3s
# 4:	learn: 0.1832766	total: 231ms	remaining: 4.38s
# 5:	learn: 0.1668958	total: 282ms	remaining: 4.41s
# 6:	learn: 0.1588808	total: 336ms	remaining: 4.46s
# 7:	learn: 0.1528589	total: 381ms	remaining: 4.38s
# 8:	learn: 0.1450445	total: 430ms	remaining: 4.35s
# 9:	learn: 0.1435430	total: 476ms	remaining: 4.29s
# 10:	learn: 0.1405705	total: 522ms	remaining: 4.22s
# 11:	learn: 0.1394585	total: 562ms	remaining: 4.12s
# 12:	learn: 0.1372860	total: 633ms	remaining: 4.24s
# 13:	learn: 0.1338752	total: 697ms	remaining: 4.28s
# 14:	learn: 0.1314075	total: 757ms	remaining: 4.29s
# 15:	learn: 0.1297645	total: 824ms	remaining: 4.33s
# 16:	learn: 0.1284126	total: 894ms	remaining: 4.36s
# 17:	learn: 0.1262739	total: 956ms	remaining: 4.35s
# 18:	learn: 0.1253170	total: 1.02s	remaining: 4.37s
# 19:	learn: 0.1230202	total: 1.09s	remaining: 4.37s
# 20:	learn: 0.1204183	total: 1.17s	remaining: 4.41s
# 21:	learn: 0.1160168	total: 1.27s	remaining: 4.49s
# 22:	learn: 0.1143964	total: 1.33s	remaining: 4.46s
# 23:	learn: 0.1137244	total: 1.4s	remaining: 4.43s
# 24:	learn: 0.1127004	total: 1.46s	remaining: 4.39s
# 25:	learn: 0.1118192	total: 1.54s	remaining: 4.38s
# 26:	learn: 0.1108499	total: 1.64s	remaining: 4.43s
# 27:	learn: 0.1097165	total: 1.73s	remaining: 4.44s
# 28:	learn: 0.1086238	total: 1.8s	remaining: 4.4s
# 29:	learn: 0.1078026	total: 1.85s	remaining: 4.32s
# 30:	learn: 0.1062136	total: 1.91s	remaining: 4.24s
# 31:	learn: 0.1055353	total: 1.96s	remaining: 4.16s
# 32:	learn: 0.1050315	total: 2.01s	remaining: 4.08s
# 33:	learn: 0.1047193	total: 2.07s	remaining: 4.03s
# 34:	learn: 0.1040732	total: 2.13s	remaining: 3.95s
# 35:	learn: 0.1034673	total: 2.19s	remaining: 3.89s
# 36:	learn: 0.1027583	total: 2.25s	remaining: 3.83s
# 37:	learn: 0.1021503	total: 2.31s	remaining: 3.76s
# 38:	learn: 0.1009945	total: 2.37s	remaining: 3.7s
# 39:	learn: 0.1004105	total: 2.42s	remaining: 3.63s
# 40:	learn: 0.0997307	total: 2.47s	remaining: 3.56s
# 41:	learn: 0.0992269	total: 2.52s	remaining: 3.49s
# 42:	learn: 0.0980505	total: 2.58s	remaining: 3.42s
# 43:	learn: 0.0976982	total: 2.63s	remaining: 3.34s
# 44:	learn: 0.0974164	total: 2.68s	remaining: 3.28s
# 45:	learn: 0.0969450	total: 2.73s	remaining: 3.21s
# 46:	learn: 0.0967569	total: 2.79s	remaining: 3.14s
# 47:	learn: 0.0953902	total: 2.84s	remaining: 3.08s
# 48:	learn: 0.0948347	total: 2.9s	remaining: 3.02s
# 49:	learn: 0.0943834	total: 2.96s	remaining: 2.96s
# 50:	learn: 0.0939689	total: 3.01s	remaining: 2.89s
# 51:	learn: 0.0935512	total: 3.06s	remaining: 2.83s
# 52:	learn: 0.0932172	total: 3.11s	remaining: 2.75s
# 53:	learn: 0.0929559	total: 3.16s	remaining: 2.69s
# 54:	learn: 0.0927413	total: 3.2s	remaining: 2.62s
# 55:	learn: 0.0925428	total: 3.25s	remaining: 2.56s
# 56:	learn: 0.0923962	total: 3.3s	remaining: 2.49s
# 57:	learn: 0.0921232	total: 3.35s	remaining: 2.43s
# 58:	learn: 0.0912500	total: 3.4s	remaining: 2.36s
# 59:	learn: 0.0909505	total: 3.44s	remaining: 2.29s
# 60:	learn: 0.0906517	total: 3.48s	remaining: 2.23s
# 61:	learn: 0.0904037	total: 3.55s	remaining: 2.17s
# 62:	learn: 0.0901206	total: 3.6s	remaining: 2.12s
# 63:	learn: 0.0896290	total: 3.66s	remaining: 2.06s
# 64:	learn: 0.0894460	total: 3.73s	remaining: 2.01s
# 65:	learn: 0.0891672	total: 3.79s	remaining: 1.95s
# 66:	learn: 0.0887993	total: 3.85s	remaining: 1.9s
# 67:	learn: 0.0879560	total: 3.92s	remaining: 1.84s
# 68:	learn: 0.0878063	total: 3.98s	remaining: 1.79s
# 69:	learn: 0.0877326	total: 4.04s	remaining: 1.73s
# 70:	learn: 0.0876015	total: 4.11s	remaining: 1.68s
# 71:	learn: 0.0873453	total: 4.16s	remaining: 1.62s
# 72:	learn: 0.0869830	total: 4.21s	remaining: 1.56s
# 73:	learn: 0.0868232	total: 4.26s	remaining: 1.5s
# 74:	learn: 0.0866781	total: 4.31s	remaining: 1.44s
# 75:	learn: 0.0861234	total: 4.36s	remaining: 1.38s
# 76:	learn: 0.0859058	total: 4.42s	remaining: 1.32s
# 77:	learn: 0.0858029	total: 4.46s	remaining: 1.26s
# 78:	learn: 0.0855793	total: 4.54s	remaining: 1.21s
# 79:	learn: 0.0853771	total: 4.6s	remaining: 1.15s
# 80:	learn: 0.0850007	total: 4.66s	remaining: 1.09s
# 81:	learn: 0.0849015	total: 4.73s	remaining: 1.04s
# 82:	learn: 0.0847148	total: 4.79s	remaining: 980ms
# 83:	learn: 0.0844650	total: 4.85s	remaining: 924ms
# 84:	learn: 0.0842966	total: 4.93s	remaining: 870ms
# 85:	learn: 0.0841451	total: 4.98s	remaining: 811ms
# 86:	learn: 0.0840163	total: 5.04s	remaining: 754ms
# 87:	learn: 0.0838309	total: 5.11s	remaining: 697ms
# 88:	learn: 0.0837296	total: 5.16s	remaining: 638ms
# 89:	learn: 0.0836237	total: 5.21s	remaining: 579ms
# 90:	learn: 0.0834898	total: 5.26s	remaining: 520ms
# 91:	learn: 0.0832619	total: 5.33s	remaining: 464ms
# 92:	learn: 0.0831588	total: 5.38s	remaining: 405ms
# 93:	learn: 0.0828996	total: 5.42s	remaining: 346ms
# 94:	learn: 0.0825747	total: 5.47s	remaining: 288ms
# 95:	learn: 0.0821255	total: 5.52s	remaining: 230ms
# 96:	learn: 0.0819448	total: 5.57s	remaining: 172ms
# 97:	learn: 0.0817133	total: 5.62s	remaining: 115ms
# 98:	learn: 0.0816302	total: 5.67s	remaining: 57.2ms
# 99:	learn: 0.0814453	total: 5.72s	remaining: 0us
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:13:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy Score of Voting Classifier is : 0.9564983061287342
# Confusion Matrix :
# [[11388   416]
#  [  714 13458]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     11804
#            1       0.97      0.95      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_vc = cohen_kappa_score(y_test, model_vc_prediction)
kappa_vc
# Out:
# 0.9124521770336184

# %%
# Models Comparison
models = pd.DataFrame({
    'Model' : ['Logistic Regression', 'KNN', 'Decision Tree Classifier', 'Random Forest Classifier','Ada Boost Classifier',
             'Gradient Boosting Classifier', 'XgBoost', 'Cat Boost', 'Extra Trees Classifier', 'LGBM', 'Voting Classifier', 'K-Fold Decision Tree'],
    'Score' : [accuracy_lr, accuracy_knn, accuracy_dt, accuracy_rf, accuracy_ada, accuracy_gb, accuracy_xgb, accuracy_cat, 
              accuracy_etc, accuracy_lgbm, accuracy_vc, model_kfdt.mean()],
    'Kappa' : [kappa_lr, kappa_knn, kappa_dt, kappa_rf, kappa_ada, kappa_gb, kappa_xgb, kappa_cat, kappa_etc, kappa_lgbm, 
              kappa_vc, model_kfdt.mean()]
})

# Sorting the results by Kappa values
models_sorted = models.sort_values(by = 'Kappa', ascending = False)
models_sorted.reset_index(drop = True, inplace = True)

# %%
# PLOT: All Kappa values as comparison

plt.bar(x=models_sorted.Model, height = models_sorted.Kappa, color = 'c', width = 0.5)
#plt.grid()
plt.title('Machine Learning Models in Prediction of Airline Passenger`s Satisfaction')
plt.xlabel('Exploration Methods', fontsize=15)
plt.ylabel('Kappa', fontsize=15)
plt.ylim(0, 1)
plt.xticks(rotation=90)
plt.rcParams['figure.figsize'] = [5, 8]

for i in models_sorted.index:
  plt.text(x = i, 
           y = models_sorted.Kappa[i], 
           s = round(models_sorted.Kappa[i], 3), 
           horizontalalignment='center',
           verticalalignment='bottom',
           size = 11)

plt.show()
