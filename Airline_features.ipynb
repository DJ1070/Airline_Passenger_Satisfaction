# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, cohen_kappa_score
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from imblearn.over_sampling import RandomOverSampler

# %%
df = pd.read_excel('./Data/satisfaction.xlsx')

# %%
df
# Out:
#             id          satisfaction_v2  Gender      Customer Type  Age  \
# 0        11112                satisfied  Female     Loyal Customer   65
# 1       110278                satisfied    Male     Loyal Customer   47
# 2       103199                satisfied  Female     Loyal Customer   15
# 3        47462                satisfied  Female     Loyal Customer   60
# 4       120011                satisfied  Female     Loyal Customer   70
# ...        ...                      ...     ...                ...  ...
# 129875  119211                satisfied  Female  disloyal Customer   29
# 129876   97768  neutral or dissatisfied    Male  disloyal Customer   63
# 129877  125368  neutral or dissatisfied    Male  disloyal Customer   69
# 129878     251  neutral or dissatisfied    Male  disloyal Customer   66
# 129879   84566  neutral or dissatisfied  Female  disloyal Customer   38
#
#          Type of Travel     Class  Flight Distance  Seat comfort  \
# 0       Personal Travel       Eco              265             0
# 1       Personal Travel  Business             2464             0
# 2       Personal Travel       Eco             2138             0
# 3       Personal Travel       Eco              623             0
# 4       Personal Travel       Eco              354             0
# ...                 ...       ...              ...           ...
# 129875  Personal Travel       Eco             1731             5
# 129876  Personal Travel  Business             2087             2
# 129877  Personal Travel       Eco             2320             3
# 129878  Personal Travel       Eco             2450             3
# 129879  Personal Travel       Eco             4307             3
#
#         Departure/Arrival time convenient  ...  Online support  \
# 0                                       0  ...               2
# 1                                       0  ...               2
# 2                                       0  ...               2
# 3                                       0  ...               3
# 4                                       0  ...               4
# ...                                   ...  ...             ...
# 129875                                  5  ...               2
# 129876                                  3  ...               1
# 129877                                  0  ...               2
# 129878                                  2  ...               2
# 129879                                  4  ...               3
#
#         Ease of Online booking  On-board service  Leg room service  \
# 0                            3                 3                 0
# 1                            3                 4                 4
# 2                            2                 3                 3
# 3                            1                 1                 0
# 4                            2                 2                 0
# ...                        ...               ...               ...
# 129875                       2                 3                 3
# 129876                       3                 2                 3
# 129877                       4                 4                 3
# 129878                       3                 3                 2
# 129879                       4                 5                 5
#
#         Baggage handling  Checkin service  Cleanliness  Online boarding  \
# 0                      3                5            3                2
# 1                      4                2            3                2
# 2                      4                4            4                2
# 3                      1                4            1                3
# 4                      2                4            2                5
# ...                  ...              ...          ...              ...
# 129875                 4                4            4                2
# 129876                 3                1            2                1
# 129877                 4                2            3                2
# 129878                 3                2            1                2
# 129879                 5                3            3                3
#
#         Departure Delay in Minutes  Arrival Delay in Minutes
# 0                                0                       0.0
# 1                              310                     305.0
# 2                                0                       0.0
# 3                                0                       0.0
# 4                                0                       0.0
# ...                            ...                       ...
# 129875                           0                       0.0
# 129876                         174                     172.0
# 129877                         155                     163.0
# 129878                         193                     205.0
# 129879                         185                     186.0
#
# [129880 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['id', 'satisfaction_v2', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
df.columns = ['ID', 'Satisfaction', 'Gender', 'Customer_type', 'Age',
       'Type_of_travel', 'Class', 'Flight_distance', 'Seat_comfort',
       'Departure_arrival_time_convenient', 'Food_and_drink', 'Gate_location',
       'Inflight_wifi_service', 'Inflight_entertainment', 'Online_support',
       'Ease_of_online_booking', 'Onboard_service', 'Leg_room_service',
       'Baggage_handling', 'Checkin_service', 'Cleanliness', 'Online_boarding',
       'Departure_delay_in_minutes', 'Arrival_delay_in_minutes']

# %%
df['Satisfaction'] = df['Satisfaction'].apply(lambda value: 1 
if value == 'satisfied' else 0)

# %%
df['Gender'] = df['Gender'].apply(lambda value: 1 
if value == 'Female' else 0)

# %%
df['Customer_type'] = df['Customer_type'].apply(lambda value: 1 
if value == 'Loyal Customer' else 0)

# %%
df['Type_of_travel'] = df['Type_of_travel'].apply(lambda value: 1 
if value == 'Business travel' else 0)

# %%
df['Class'] = df['Class'].apply(lambda value: 0 
if value == 'Eco' else 1
if value == 'Eco Plus' else 2)

# %%
df.dtypes
# Out:
# ID                                     int64
# Satisfaction                           int64
# Gender                                 int64
# Customer_type                          int64
# Age                                    int64
# Type_of_travel                         int64
# Class                                  int64
# Flight_distance                        int64
# Seat_comfort                           int64
# Departure_arrival_time_convenient      int64
# Food_and_drink                         int64
# Gate_location                          int64
# Inflight_wifi_service                  int64
# Inflight_entertainment                 int64
# Online_support                         int64
# Ease_of_online_booking                 int64
# Onboard_service                        int64
# Leg_room_service                       int64
# Baggage_handling                       int64
# Checkin_service                        int64
# Cleanliness                            int64
# Online_boarding                        int64
# Departure_delay_in_minutes             int64
# Arrival_delay_in_minutes             float64
# dtype: object

# %%
df = df.drop(['ID', 'Departure_delay_in_minutes'], axis = 1)

# %%
df
# Out:
#         Satisfaction  Gender  Customer_type  Age  Type_of_travel  Class  \
# 0                  1       1              1   65               0      0
# 1                  1       0              1   47               0      2
# 2                  1       1              1   15               0      0
# 3                  1       1              1   60               0      0
# 4                  1       1              1   70               0      0
# ...              ...     ...            ...  ...             ...    ...
# 129875             1       1              0   29               0      0
# 129876             0       0              0   63               0      2
# 129877             0       0              0   69               0      0
# 129878             0       0              0   66               0      0
# 129879             0       1              0   38               0      0
#
#         Flight_distance  Seat_comfort  Departure_arrival_time_convenient  \
# 0                   265             0                                  0
# 1                  2464             0                                  0
# 2                  2138             0                                  0
# 3                   623             0                                  0
# 4                   354             0                                  0
# ...                 ...           ...                                ...
# 129875             1731             5                                  5
# 129876             2087             2                                  3
# 129877             2320             3                                  0
# 129878             2450             3                                  2
# 129879             4307             3                                  4
#
#         Food_and_drink  ...  Inflight_entertainment  Online_support  \
# 0                    0  ...                       4               2
# 1                    0  ...                       2               2
# 2                    0  ...                       0               2
# 3                    0  ...                       4               3
# 4                    0  ...                       3               4
# ...                ...  ...                     ...             ...
# 129875               5  ...                       5               2
# 129876               2  ...                       1               1
# 129877               3  ...                       2               2
# 129878               3  ...                       2               2
# 129879               3  ...                       3               3
#
#         Ease_of_online_booking  Onboard_service  Leg_room_service  \
# 0                            3                3                 0
# 1                            3                4                 4
# 2                            2                3                 3
# 3                            1                1                 0
# 4                            2                2                 0
# ...                        ...              ...               ...
# 129875                       2                3                 3
# 129876                       3                2                 3
# 129877                       4                4                 3
# 129878                       3                3                 2
# 129879                       4                5                 5
#
#         Baggage_handling  Checkin_service  Cleanliness  Online_boarding  \
# 0                      3                5            3                2
# 1                      4                2            3                2
# 2                      4                4            4                2
# 3                      1                4            1                3
# 4                      2                4            2                5
# ...                  ...              ...          ...              ...
# 129875                 4                4            4                2
# 129876                 3                1            2                1
# 129877                 4                2            3                2
# 129878                 3                2            1                2
# 129879                 5                3            3                3
#
#         Arrival_delay_in_minutes
# 0                            0.0
# 1                          305.0
# 2                            0.0
# 3                            0.0
# 4                            0.0
# ...                          ...
# 129875                       0.0
# 129876                     172.0
# 129877                     163.0
# 129878                     205.0
# 129879                     186.0
#
# [129880 rows x 22 columns]

# %%
df[df.Arrival_delay_in_minutes.isna() == True]
# Out:
#         Satisfaction  Gender  Customer_type  Age  Type_of_travel  Class  \
# 145                1       1              1   21               0      0
# 246                1       0              1   28               0      0
# 710                1       0              1   28               0      0
# 736                1       0              1    9               0      0
# 818                0       0              1    9               0      0
# ...              ...     ...            ...  ...             ...    ...
# 127739             1       0              1   44               1      2
# 128131             1       0              1   39               1      2
# 128710             1       1              1   45               1      0
# 129774             1       0              0   49               0      0
# 129873             1       1              0   63               0      0
#
#         Flight_distance  Seat_comfort  Departure_arrival_time_convenient  \
# 145                4804             0                                  2
# 246                1364             0                                  3
# 710                1792             0                                  5
# 736                1862             0                                  5
# 818                1668             1                                  0
# ...                 ...           ...                                ...
# 127739             3431             2                                  2
# 128131             1595             4                                  4
# 128710              871             5                                  1
# 129774             1594             5                                  4
# 129873             1942             5                                  5
#
#         Food_and_drink  ...  Inflight_entertainment  Online_support  \
# 145                  0  ...                       0               5
# 246                  0  ...                       0               4
# 710                  0  ...                       0               5
# 736                  0  ...                       0               3
# 818                  1  ...                       1               4
# ...                ...  ...                     ...             ...
# 127739               3  ...                       2               4
# 128131               4  ...                       4               5
# 128710               1  ...                       5               2
# 129774               5  ...                       5               3
# 129873               4  ...                       4               3
#
#         Ease_of_online_booking  Onboard_service  Leg_room_service  \
# 145                          5                4                 1
# 246                          2                1                 1
# 710                          5                4                 4
# 736                          3                5                 3
# 818                          4                4                 5
# ...                        ...              ...               ...
# 127739                       5                5                 5
# 128131                       5                5                 5
# 128710                       5                5                 5
# 129774                       3                1                 4
# 129873                       3                5                 2
#
#         Baggage_handling  Checkin_service  Cleanliness  Online_boarding  \
# 145                    4                2            3                5
# 246                    3                4            3                2
# 710                    5                3            4                5
# 736                    4                4            4                3
# 818                    1                5            1                4
# ...                  ...              ...          ...              ...
# 127739                 5                5            5                4
# 128131                 5                3            5                5
# 128710                 5                1            5                5
# 129774                 3                3            4                3
# 129873                 5                3            5                3
#
#         Arrival_delay_in_minutes
# 145                          NaN
# 246                          NaN
# 710                          NaN
# 736                          NaN
# 818                          NaN
# ...                          ...
# 127739                       NaN
# 128131                       NaN
# 128710                       NaN
# 129774                       NaN
# 129873                       NaN
#
# [393 rows x 22 columns]

# %%
df.Arrival_delay_in_minutes = df.Arrival_delay_in_minutes.fillna(df.Arrival_delay_in_minutes.mean())

# %%
fig, ax = plt.subplots(figsize=(24, 16)) 
sns.heatmap(df.corr(), annot=True, ax = ax)
# Out:
# <AxesSubplot:>

# %%
X = df.iloc[:,1:]
y = np.array(df['Satisfaction'])

X_scaled = StandardScaler().fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=1)

# %%
# Logistic Regression
model_lr = LogisticRegression().fit(X_train, y_train)
model_lr_prediction = model_lr.predict(X_test)
accuracy_lr = accuracy_score(y_test, model_lr_prediction)

conf_lr = confusion_matrix(y_test, model_lr_prediction)
clf_report_lr = classification_report(y_test, model_lr_prediction)

print(f"Accuracy Score of Logistic Regression is : {accuracy_lr}")
print(f"Confusion Matrix : \n{conf_lr}")
print(f"Classification Report : \n{clf_report_lr}")
# Out:
# Accuracy Score of Logistic Regression is : 0.8379273175238682
# Confusion Matrix :
# [[ 9665  2139]
#  [ 2071 12101]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82     11804
#            1       0.85      0.85      0.85     14172
#
#     accuracy                           0.84     25976
#    macro avg       0.84      0.84      0.84     25976
# weighted avg       0.84      0.84      0.84     25976

# %%
kappa_lr = cohen_kappa_score(y_test, model_lr_prediction)
kappa_lr
# Out:
# 0.6729809142478427

# %%
# Decision Tree
model_dt = tree.DecisionTreeClassifier().fit(X_train, y_train)
model_dt_prediction = model_dt.predict(X_test)
accuracy_dt = accuracy_score(y_test, model_dt_prediction)

conf_dt = confusion_matrix(y_test, model_dt_prediction)
clf_report_dt = classification_report(y_test, model_dt_prediction)

print(f"Accuracy Score of Decision Tree is : {accuracy_dt}")
print(f"Confusion Matrix : \n{conf_dt}")
print(f"Classification Report : \n{clf_report_dt}")
# Out:
# Accuracy Score of Decision Tree is : 0.9429088389282414
# Confusion Matrix :
# [[11053   751]
#  [  732 13440]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94     11804
#            1       0.95      0.95      0.95     14172
#
#     accuracy                           0.94     25976
#    macro avg       0.94      0.94      0.94     25976
# weighted avg       0.94      0.94      0.94     25976

# %%
kappa_dt = cohen_kappa_score(y_test, model_dt_prediction)
kappa_dt
# Out:
# 0.8848453465649039

# %%
# K-Fold DecisionTree
model_kfdt = cross_val_score(tree.DecisionTreeClassifier(max_depth = 7), X, y, cv=700)
print('Maximum: ', model_kfdt.max())
print('Mean: ', model_kfdt.mean())

model_kfdt = pd.Series(model_kfdt)
model_kfdt.plot()
# Out:
# Maximum:  1.0
# Mean:  0.9108106032299582
# <AxesSubplot:>

# %%
# KNN
model_knn = KNeighborsClassifier(n_neighbors = 7, metric = 'minkowski', p = 2).fit(X_train, y_train)
model_knn_prediction = model_knn.predict(X_test)
accuracy_knn = accuracy_score(y_test, model_knn_prediction)

conf_knn = confusion_matrix(y_test, model_knn_prediction)
clf_report_knn = classification_report(y_test, model_knn_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_knn}")
print(f"Confusion Matrix : \n{conf_knn}")
print(f"Classification Report : \n{clf_report_knn}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.9286264243917463
# Confusion Matrix :
# [[11153   651]
#  [ 1203 12969]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92     11804
#            1       0.95      0.92      0.93     14172
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
kappa_knn = cohen_kappa_score(y_test, model_knn_prediction)
kappa_knn
# Out:
# 0.8566168116757228

# %%
# Random Forest Classifier
model_rf = RandomForestClassifier(n_estimators=1500, criterion = 'entropy', random_state = 6).fit(X_train, y_train)
model_rf_prediction = model_rf.predict(X_test)
rf = accuracy_score(y_test, model_rf_prediction)
print('Accuracy Score: ', rf)
# Out:
# Accuracy Score:  0.9607329842931938

# %%
kappa_rf = cohen_kappa_score(y_test, model_rf_prediction)
print('Kappa: ', kappa_rf)
# Out:
# Kappa:  0.920956666953379

# %%
# Random Forest
model_rf = RandomForestClassifier(n_estimators=1500).fit(X_train, y_train)
model_rf_prediction = model_rf.predict(X_test)
accuracy_rf = accuracy_score(y_test, model_rf_prediction)

conf_rf = confusion_matrix(y_test, model_rf_prediction)
clf_report_rf = classification_report(y_test, model_rf_prediction)

print(f"Accuracy Score of Random Forest is : {accuracy_rf}")
print(f"Confusion Matrix : \n{conf_rf}")
print(f"Classification Report : \n{clf_report_rf}")
# Out:
# Accuracy Score of Random Forest is : 0.9608484755158608
# Confusion Matrix :
# [[11419   385]
#  [  632 13540]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_rf = cohen_kappa_score(y_test, model_rf_prediction)
kappa_rf
# Out:
# 0.9211785676674397

# %%
# Ada Boost
model_ada = AdaBoostClassifier(n_estimators = 1000).fit(X_train, y_train)
model_ada_prediction = model_ada.predict(X_test)
accuracy_ada = accuracy_score(y_test, model_ada_prediction)

conf_ada = confusion_matrix(y_test, model_ada_prediction)
clf_report_ada = classification_report(y_test, model_ada_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_ada}")
print(f"Confusion Matrix : \n{conf_ada}")
print(f"Classification Report : \n{clf_report_ada}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.9061056359716662
# Confusion Matrix :
# [[10654  1150]
#  [ 1289 12883]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90     11804
#            1       0.92      0.91      0.91     14172
#
#     accuracy                           0.91     25976
#    macro avg       0.91      0.91      0.91     25976
# weighted avg       0.91      0.91      0.91     25976

# %%
kappa_ada = cohen_kappa_score(y_test, model_ada_prediction)
kappa_ada
# Out:
# 0.810823717218921

# %%
# Gradient Boosting Classifier
model_gb = GradientBoostingClassifier().fit(X_train, y_train)
model_gb_prediction = model_gb.predict(X_test)

accuracy_gb = accuracy_score(y_test, model_gb_prediction)
conf_gb = confusion_matrix(y_test, model_gb_prediction)
clf_report_gb = classification_report(y_test, model_gb_prediction)

print(f"Accuracy Score of Ada Boost Classifier is : {accuracy_gb}")
print(f"Confusion Matrix : \n{conf_gb}")
print(f"Classification Report : \n{clf_report_gb}")
# Out:
# Accuracy Score of Ada Boost Classifier is : 0.9274715121650755
# Confusion Matrix :
# [[10864   940]
#  [  944 13228]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     11804
#            1       0.93      0.93      0.93     14172
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
kappa_gb = cohen_kappa_score(y_test, model_gb_prediction)
kappa_gb
# Out:
# 0.853731590524546

# %%
# XgBoost Classifier
model_xgb = XGBClassifier(booster = 'gbtree', learning_rate = 0.1, max_depth = 5, n_estimators = 180).fit(X_train, y_train)
model_xgb_prediction = model_xgb.predict(X_test)

accuracy_xgb = accuracy_score(y_test, model_xgb_prediction)
conf_xgb = confusion_matrix(y_test, model_xgb_prediction)
clf_report_xgb = classification_report(y_test, model_xgb_prediction)

print(f"Accuracy Score of XgBoost Classifier is : {accuracy_xgb}")
print(f"Confusion Matrix : \n{conf_xgb}")
print(f"Classification Report : \n{clf_report_xgb}")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:24:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy Score of XgBoost Classifier is : 0.9569217739451802
# Confusion Matrix :
# [[11334   470]
#  [  649 13523]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95     11804
#            1       0.97      0.95      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_xgb = cohen_kappa_score(y_test, model_xgb_prediction)
kappa_xgb
# Out:
# 0.91323148596489

# %%
# Cat Boost Classifier
model_cat = CatBoostClassifier(iterations=100).fit(X_train, y_train)
model_cat_prediction = model_cat.predict(X_test)

accuracy_cat = accuracy_score(y_test, model_cat_prediction)
conf_cat = confusion_matrix(y_test, model_cat_prediction)
clf_report_cat = classification_report(y_test, model_cat_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_cat}")
print(f"Confusion Matrix : \n{conf_cat}")
print(f"Classification Report : \n{clf_report_cat}")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.3443416	total: 300ms	remaining: 29.7s
# 1:	learn: 0.2609934	total: 408ms	remaining: 20s
# 2:	learn: 0.2153750	total: 500ms	remaining: 16.2s
# 3:	learn: 0.2025242	total: 613ms	remaining: 14.7s
# 4:	learn: 0.1824307	total: 702ms	remaining: 13.3s
# 5:	learn: 0.1729295	total: 778ms	remaining: 12.2s
# 6:	learn: 0.1628843	total: 842ms	remaining: 11.2s
# 7:	learn: 0.1574423	total: 956ms	remaining: 11s
# 8:	learn: 0.1537504	total: 1.11s	remaining: 11.2s
# 9:	learn: 0.1517733	total: 1.24s	remaining: 11.2s
# 10:	learn: 0.1409069	total: 1.35s	remaining: 10.9s
# 11:	learn: 0.1393028	total: 1.42s	remaining: 10.4s
# 12:	learn: 0.1372074	total: 1.49s	remaining: 9.96s
# 13:	learn: 0.1326453	total: 1.56s	remaining: 9.58s
# 14:	learn: 0.1297816	total: 1.61s	remaining: 9.16s
# 15:	learn: 0.1263587	total: 1.67s	remaining: 8.78s
# 16:	learn: 0.1247056	total: 1.74s	remaining: 8.47s
# 17:	learn: 0.1230358	total: 1.78s	remaining: 8.13s
# 18:	learn: 0.1214883	total: 1.83s	remaining: 7.82s
# 19:	learn: 0.1203671	total: 1.88s	remaining: 7.53s
# 20:	learn: 0.1187036	total: 1.95s	remaining: 7.33s
# 21:	learn: 0.1160094	total: 2s	remaining: 7.09s
# 22:	learn: 0.1141365	total: 2.06s	remaining: 6.92s
# 23:	learn: 0.1131814	total: 2.16s	remaining: 6.83s
# 24:	learn: 0.1117540	total: 2.22s	remaining: 6.66s
# 25:	learn: 0.1106259	total: 2.29s	remaining: 6.52s
# 26:	learn: 0.1085090	total: 2.36s	remaining: 6.38s
# 27:	learn: 0.1064992	total: 2.42s	remaining: 6.21s
# 28:	learn: 0.1058335	total: 2.47s	remaining: 6.05s
# 29:	learn: 0.1043866	total: 2.54s	remaining: 5.93s
# 30:	learn: 0.1033528	total: 2.6s	remaining: 5.79s
# 31:	learn: 0.1029987	total: 2.66s	remaining: 5.65s
# 32:	learn: 0.1021288	total: 2.72s	remaining: 5.53s
# 33:	learn: 0.1017387	total: 2.79s	remaining: 5.41s
# 34:	learn: 0.1012572	total: 2.85s	remaining: 5.29s
# 35:	learn: 0.1005535	total: 2.9s	remaining: 5.16s
# 36:	learn: 0.1002755	total: 2.96s	remaining: 5.05s
# 37:	learn: 0.0999435	total: 3.02s	remaining: 4.93s
# 38:	learn: 0.0995712	total: 3.08s	remaining: 4.82s
# 39:	learn: 0.0989549	total: 3.14s	remaining: 4.71s
# 40:	learn: 0.0980829	total: 3.21s	remaining: 4.61s
# 41:	learn: 0.0977642	total: 3.26s	remaining: 4.5s
# 42:	learn: 0.0974564	total: 3.31s	remaining: 4.39s
# 43:	learn: 0.0970534	total: 3.36s	remaining: 4.27s
# 44:	learn: 0.0961090	total: 3.41s	remaining: 4.17s
# 45:	learn: 0.0950714	total: 3.46s	remaining: 4.06s
# 46:	learn: 0.0945642	total: 3.52s	remaining: 3.97s
# 47:	learn: 0.0939605	total: 3.57s	remaining: 3.87s
# 48:	learn: 0.0936201	total: 3.65s	remaining: 3.8s
# 49:	learn: 0.0931786	total: 3.71s	remaining: 3.71s
# 50:	learn: 0.0925471	total: 3.77s	remaining: 3.62s
# 51:	learn: 0.0923433	total: 3.83s	remaining: 3.53s
# 52:	learn: 0.0918060	total: 3.9s	remaining: 3.46s
# 53:	learn: 0.0914440	total: 3.96s	remaining: 3.37s
# 54:	learn: 0.0910220	total: 4.02s	remaining: 3.29s
# 55:	learn: 0.0906555	total: 4.09s	remaining: 3.22s
# 56:	learn: 0.0902489	total: 4.15s	remaining: 3.13s
# 57:	learn: 0.0900352	total: 4.21s	remaining: 3.05s
# 58:	learn: 0.0897264	total: 4.28s	remaining: 2.97s
# 59:	learn: 0.0894608	total: 4.34s	remaining: 2.89s
# 60:	learn: 0.0892105	total: 4.39s	remaining: 2.81s
# 61:	learn: 0.0888987	total: 4.46s	remaining: 2.74s
# 62:	learn: 0.0886758	total: 4.53s	remaining: 2.66s
# 63:	learn: 0.0884561	total: 4.59s	remaining: 2.58s
# 64:	learn: 0.0882889	total: 4.66s	remaining: 2.51s
# 65:	learn: 0.0881306	total: 4.71s	remaining: 2.43s
# 66:	learn: 0.0878895	total: 4.77s	remaining: 2.35s
# 67:	learn: 0.0874639	total: 4.84s	remaining: 2.28s
# 68:	learn: 0.0872438	total: 4.9s	remaining: 2.2s
# 69:	learn: 0.0867999	total: 4.96s	remaining: 2.13s
# 70:	learn: 0.0864322	total: 5.1s	remaining: 2.08s
# 71:	learn: 0.0861267	total: 5.17s	remaining: 2.01s
# 72:	learn: 0.0858066	total: 5.25s	remaining: 1.94s
# 73:	learn: 0.0855821	total: 5.34s	remaining: 1.88s
# 74:	learn: 0.0854414	total: 5.44s	remaining: 1.81s
# 75:	learn: 0.0852946	total: 5.52s	remaining: 1.74s
# 76:	learn: 0.0850122	total: 5.6s	remaining: 1.67s
# 77:	learn: 0.0847526	total: 5.69s	remaining: 1.6s
# 78:	learn: 0.0844347	total: 5.76s	remaining: 1.53s
# 79:	learn: 0.0842463	total: 5.86s	remaining: 1.46s
# 80:	learn: 0.0841123	total: 5.96s	remaining: 1.4s
# 81:	learn: 0.0838147	total: 6.05s	remaining: 1.33s
# 82:	learn: 0.0833942	total: 6.11s	remaining: 1.25s
# 83:	learn: 0.0832626	total: 6.17s	remaining: 1.17s
# 84:	learn: 0.0830241	total: 6.24s	remaining: 1.1s
# 85:	learn: 0.0828257	total: 6.3s	remaining: 1.03s
# 86:	learn: 0.0825655	total: 6.45s	remaining: 963ms
# 87:	learn: 0.0822938	total: 6.56s	remaining: 894ms
# 88:	learn: 0.0819348	total: 6.69s	remaining: 827ms
# 89:	learn: 0.0818215	total: 6.8s	remaining: 756ms
# 90:	learn: 0.0815144	total: 6.91s	remaining: 683ms
# 91:	learn: 0.0814497	total: 7s	remaining: 609ms
# 92:	learn: 0.0813251	total: 7.1s	remaining: 534ms
# 93:	learn: 0.0813250	total: 7.16s	remaining: 457ms
# 94:	learn: 0.0812273	total: 7.26s	remaining: 382ms
# 95:	learn: 0.0811686	total: 7.33s	remaining: 305ms
# 96:	learn: 0.0808232	total: 7.39s	remaining: 229ms
# 97:	learn: 0.0806955	total: 7.45s	remaining: 152ms
# 98:	learn: 0.0805719	total: 7.51s	remaining: 75.9ms
# 99:	learn: 0.0803535	total: 7.59s	remaining: 0us
# Accuracy Score of Cat Boost Classifier is : 0.9591931013242994
# Confusion Matrix :
# [[11345   459]
#  [  601 13571]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_cat = cohen_kappa_score(y_test, model_cat_prediction)
kappa_cat
# Out:
# 0.9177849092973457

# %%
# Extra Trees Classifier
model_etc = ExtraTreesClassifier().fit(X_train, y_train)
model_etc_prediction = model_etc.predict(X_test)

accuracy_etc = accuracy_score(y_test, model_etc_prediction)
conf_etc = confusion_matrix(y_test, model_etc_prediction)
clf_report_etc = classification_report(y_test, model_etc_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_etc}")
print(f"Confusion Matrix : \n{conf_etc}")
print(f"Classification Report : \n{clf_report_etc}")
# Out:
# Accuracy Score of Cat Boost Classifier is : 0.9601555281798583
# Confusion Matrix :
# [[11401   403]
#  [  632 13540]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     11804
#            1       0.97      0.96      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_etc = cohen_kappa_score(y_test, model_etc_prediction)
kappa_etc
# Out:
# 0.9197732951540243

# %%
# LGBM Classifier
model_lgbm = LGBMClassifier(learning_rate = 1).fit(X_train, y_train)
model_lgbm_prediction = model_lgbm.predict(X_test)

accuracy_lgbm = accuracy_score(y_test, model_lgbm_prediction)
conf_lgbm = confusion_matrix(y_test, model_lgbm_prediction)
clf_report_lgbm = classification_report(y_test, model_lgbm_prediction)

print(f"Accuracy Score of Cat Boost Classifier is : {accuracy_lgbm}")
print(f"Confusion Matrix : \n{conf_lgbm}")
print(f"Classification Report : \n{clf_report_lgbm}")
# Out:
# Accuracy Score of Cat Boost Classifier is : 0.9275100092392978
# Confusion Matrix :
# [[10904   900]
#  [  983 13189]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     11804
#            1       0.94      0.93      0.93     14172
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
kappa_lgbm = cohen_kappa_score(y_test, model_lgbm_prediction)
kappa_lgbm
# Out:
# 0.853890920405084

# %%
# Voting Classifier
classifiers = [('Gradient Boosting Classifier', model_gb), ('Cat Boost Classifier', model_cat), ('XGboost', model_xgb),  
               ('Decision Tree', model_dt), ('Extra Tree', model_etc), ('Light Gradient', model_lgbm), ('Random Forest', model_rf), 
               ('Ada Boost', model_ada), ('Logistic', model_lr), ('Knn', model_knn)]
model_vc = VotingClassifier(estimators = classifiers).fit(X_train, y_train)
model_vc_prediction = model_vc.predict(X_test)

accuracy_vc = accuracy_score(y_test, model_vc_prediction)
conf_vc = confusion_matrix(y_test, model_vc_prediction)
clf_report_vc = classification_report(y_test, model_vc_prediction)

print(f"Accuracy Score of Voting Classifier is : {accuracy_vc}")
print(f"Confusion Matrix : \n{conf_vc}")
print(f"Classification Report : \n{clf_report_vc}")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.3443416	total: 85.3ms	remaining: 8.45s
# 1:	learn: 0.2609934	total: 201ms	remaining: 9.83s
# 2:	learn: 0.2153750	total: 335ms	remaining: 10.8s
# 3:	learn: 0.2025242	total: 496ms	remaining: 11.9s
# 4:	learn: 0.1824307	total: 591ms	remaining: 11.2s
# 5:	learn: 0.1729295	total: 652ms	remaining: 10.2s
# 6:	learn: 0.1628843	total: 722ms	remaining: 9.59s
# 7:	learn: 0.1574423	total: 785ms	remaining: 9.03s
# 8:	learn: 0.1537504	total: 856ms	remaining: 8.65s
# 9:	learn: 0.1517733	total: 913ms	remaining: 8.21s
# 10:	learn: 0.1409069	total: 988ms	remaining: 7.99s
# 11:	learn: 0.1393028	total: 1.05s	remaining: 7.7s
# 12:	learn: 0.1372074	total: 1.11s	remaining: 7.41s
# 13:	learn: 0.1326453	total: 1.17s	remaining: 7.21s
# 14:	learn: 0.1297816	total: 1.23s	remaining: 6.99s
# 15:	learn: 0.1263587	total: 1.29s	remaining: 6.8s
# 16:	learn: 0.1247056	total: 1.37s	remaining: 6.67s
# 17:	learn: 0.1230358	total: 1.44s	remaining: 6.54s
# 18:	learn: 0.1214883	total: 1.51s	remaining: 6.44s
# 19:	learn: 0.1203671	total: 1.58s	remaining: 6.33s
# 20:	learn: 0.1187036	total: 1.65s	remaining: 6.2s
# 21:	learn: 0.1160094	total: 1.71s	remaining: 6.05s
# 22:	learn: 0.1141365	total: 1.77s	remaining: 5.94s
# 23:	learn: 0.1131814	total: 1.84s	remaining: 5.82s
# 24:	learn: 0.1117540	total: 1.9s	remaining: 5.7s
# 25:	learn: 0.1106259	total: 1.97s	remaining: 5.61s
# 26:	learn: 0.1085090	total: 2.04s	remaining: 5.52s
# 27:	learn: 0.1064992	total: 2.11s	remaining: 5.42s
# 28:	learn: 0.1058335	total: 2.17s	remaining: 5.32s
# 29:	learn: 0.1043866	total: 2.23s	remaining: 5.22s
# 30:	learn: 0.1033528	total: 2.29s	remaining: 5.1s
# 31:	learn: 0.1029987	total: 2.37s	remaining: 5.03s
# 32:	learn: 0.1021288	total: 2.43s	remaining: 4.93s
# 33:	learn: 0.1017387	total: 2.48s	remaining: 4.81s
# 34:	learn: 0.1012572	total: 2.53s	remaining: 4.7s
# 35:	learn: 0.1005535	total: 2.58s	remaining: 4.6s
# 36:	learn: 0.1002755	total: 2.65s	remaining: 4.52s
# 37:	learn: 0.0999435	total: 2.72s	remaining: 4.44s
# 38:	learn: 0.0995712	total: 2.81s	remaining: 4.4s
# 39:	learn: 0.0989549	total: 2.9s	remaining: 4.35s
# 40:	learn: 0.0980829	total: 3s	remaining: 4.32s
# 41:	learn: 0.0977642	total: 3.1s	remaining: 4.28s
# 42:	learn: 0.0974564	total: 3.19s	remaining: 4.22s
# 43:	learn: 0.0970534	total: 3.28s	remaining: 4.17s
# 44:	learn: 0.0961090	total: 3.36s	remaining: 4.11s
# 45:	learn: 0.0950714	total: 3.43s	remaining: 4.03s
# 46:	learn: 0.0945642	total: 3.49s	remaining: 3.93s
# 47:	learn: 0.0939605	total: 3.54s	remaining: 3.84s
# 48:	learn: 0.0936201	total: 3.6s	remaining: 3.75s
# 49:	learn: 0.0931786	total: 3.65s	remaining: 3.65s
# 50:	learn: 0.0925471	total: 3.71s	remaining: 3.56s
# 51:	learn: 0.0923433	total: 3.77s	remaining: 3.48s
# 52:	learn: 0.0918060	total: 3.84s	remaining: 3.4s
# 53:	learn: 0.0914440	total: 3.89s	remaining: 3.32s
# 54:	learn: 0.0910220	total: 3.96s	remaining: 3.24s
# 55:	learn: 0.0906555	total: 4.02s	remaining: 3.16s
# 56:	learn: 0.0902489	total: 4.09s	remaining: 3.09s
# 57:	learn: 0.0900352	total: 4.15s	remaining: 3.01s
# 58:	learn: 0.0897264	total: 4.21s	remaining: 2.93s
# 59:	learn: 0.0894608	total: 4.28s	remaining: 2.85s
# 60:	learn: 0.0892105	total: 4.34s	remaining: 2.78s
# 61:	learn: 0.0888987	total: 4.4s	remaining: 2.7s
# 62:	learn: 0.0886758	total: 4.47s	remaining: 2.62s
# 63:	learn: 0.0884561	total: 4.52s	remaining: 2.54s
# 64:	learn: 0.0882889	total: 4.57s	remaining: 2.46s
# 65:	learn: 0.0881306	total: 4.63s	remaining: 2.38s
# 66:	learn: 0.0878895	total: 4.68s	remaining: 2.3s
# 67:	learn: 0.0874639	total: 4.73s	remaining: 2.22s
# 68:	learn: 0.0872438	total: 4.78s	remaining: 2.15s
# 69:	learn: 0.0867999	total: 4.84s	remaining: 2.08s
# 70:	learn: 0.0864322	total: 4.91s	remaining: 2s
# 71:	learn: 0.0861267	total: 4.97s	remaining: 1.93s
# 72:	learn: 0.0858066	total: 5.04s	remaining: 1.86s
# 73:	learn: 0.0855821	total: 5.11s	remaining: 1.79s
# 74:	learn: 0.0854414	total: 5.17s	remaining: 1.72s
# 75:	learn: 0.0852946	total: 5.22s	remaining: 1.65s
# 76:	learn: 0.0850122	total: 5.29s	remaining: 1.58s
# 77:	learn: 0.0847526	total: 5.36s	remaining: 1.51s
# 78:	learn: 0.0844347	total: 5.43s	remaining: 1.44s
# 79:	learn: 0.0842463	total: 5.53s	remaining: 1.38s
# 80:	learn: 0.0841123	total: 5.63s	remaining: 1.32s
# 81:	learn: 0.0838147	total: 5.75s	remaining: 1.26s
# 82:	learn: 0.0833942	total: 5.88s	remaining: 1.2s
# 83:	learn: 0.0832626	total: 5.97s	remaining: 1.14s
# 84:	learn: 0.0830241	total: 6.08s	remaining: 1.07s
# 85:	learn: 0.0828257	total: 6.18s	remaining: 1.01s
# 86:	learn: 0.0825655	total: 6.29s	remaining: 940ms
# 87:	learn: 0.0822938	total: 6.4s	remaining: 873ms
# 88:	learn: 0.0819348	total: 6.47s	remaining: 800ms
# 89:	learn: 0.0818215	total: 6.56s	remaining: 729ms
# 90:	learn: 0.0815144	total: 6.62s	remaining: 655ms
# 91:	learn: 0.0814497	total: 6.68s	remaining: 581ms
# 92:	learn: 0.0813251	total: 6.74s	remaining: 507ms
# 93:	learn: 0.0813250	total: 6.77s	remaining: 432ms
# 94:	learn: 0.0812273	total: 6.84s	remaining: 360ms
# 95:	learn: 0.0811686	total: 6.89s	remaining: 287ms
# 96:	learn: 0.0808232	total: 6.96s	remaining: 215ms
# 97:	learn: 0.0806955	total: 7.04s	remaining: 144ms
# 98:	learn: 0.0805719	total: 7.1s	remaining: 71.7ms
# 99:	learn: 0.0803535	total: 7.15s	remaining: 0us
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:26:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy Score of Voting Classifier is : 0.9574607329842932
# Confusion Matrix :
# [[11401   403]
#  [  702 13470]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     11804
#            1       0.97      0.95      0.96     14172
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
kappa_vc = cohen_kappa_score(y_test, model_vc_prediction)
kappa_vc
# Out:
# 0.9143896804195726

# %%
# Models Comparison
models = pd.DataFrame({
    'Model' : ['Logistic Regression', 'KNN', 'Decision Tree Classifier', 'Random Forest Classifier','Ada Boost Classifier',
             'Gradient Boosting Classifier', 'XgBoost', 'Cat Boost', 'Extra Trees Classifier', 'LGBM', 'Voting Classifier', 'K-Fold Decision Tree'],
    'Score' : [accuracy_lr, accuracy_knn, accuracy_dt, accuracy_rf, accuracy_ada, accuracy_gb, accuracy_xgb, accuracy_cat, 
              accuracy_etc, accuracy_lgbm, accuracy_vc, model_kfdt.mean()],
    'Kappa' : [kappa_lr, kappa_knn, kappa_dt, kappa_rf, kappa_ada, kappa_gb, kappa_xgb, kappa_cat, kappa_etc, kappa_lgbm, 
              kappa_vc, model_kfdt.mean()]
})

# Sorting the results by Kappa values
models_sorted = models.sort_values(by = 'Kappa', ascending = False)
models_sorted.reset_index(drop = True, inplace = True)
models_sorted
# Out:
#                            Model     Score     Kappa
# 0       Random Forest Classifier  0.960848  0.921179
# 1         Extra Trees Classifier  0.960156  0.919773
# 2                      Cat Boost  0.959193  0.917785
# 3              Voting Classifier  0.957461  0.914390
# 4                        XgBoost  0.956922  0.913231
# 5           K-Fold Decision Tree  0.910811  0.910811
# 6       Decision Tree Classifier  0.942909  0.884845
# 7                            KNN  0.928626  0.856617
# 8                           LGBM  0.927510  0.853891
# 9   Gradient Boosting Classifier  0.927472  0.853732
# 10          Ada Boost Classifier  0.906106  0.810824
# 11           Logistic Regression  0.837927  0.672981

# %%
# PLOT: All Kappa values as comparison

plt.bar(x=models_sorted.Model, height = models_sorted.Kappa, color = 'c', width = 0.5)
#plt.grid()
plt.title('Machine Learning Models in Prediction of Airline Passenger`s Satisfaction')
plt.xlabel('Exploration Methods', fontsize=15)
plt.ylabel('Kappa', fontsize=15)
plt.ylim(0, 1)
plt.xticks(rotation=90)
plt.rcParams['figure.figsize'] = [5, 8]

for i in models_sorted.index:
  plt.text(x = i, 
           y = models_sorted.Kappa[i], 
           s = round(models_sorted.Kappa[i], 3), 
           horizontalalignment='center',
           verticalalignment='bottom',
           size = 11)

plt.show()
